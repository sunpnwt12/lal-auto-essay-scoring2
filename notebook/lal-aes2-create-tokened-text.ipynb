# %%
import numpy as np
import pandas as pd
import polars as pl
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, f1_score, roc_auc_score, recall_score, precision_score
import torch
from transformers import AutoTokenizer
from nltk.tokenize import sent_tokenize
import pickle
from scipy.special import softmax

# %%
train_dropped = ['e9be80d', '6017fea']
# dt_map_8 = {
#     'Unannotated': 0,
#     'Lead': 1,
#     'Position': 2,
#     'Claim': 3,
#     'Evidence': 4,
#     'Concluding Statement': 5,
#     'Counterclaim': 6,
#     'Rebuttal': 7,
#     'Repeated': -1
# }
dt_map = {
    'Lead': 0,
    'Position': 1,
    'Claim': 2,
    'Evidence': 3,
    'Concluding Statement': 4,
    'Counterclaim': 5,
    'Rebuttal': 6,
    'Repeated': -1
}

rev_dt_map = {v: k for k, v in dt_map.items()}

token_dt_map = {
    'Unannotated': '<Unannotated>',
    'Lead': '<Lead>',
    'Position': '<Position>',
    'Claim': '<Claim>',
    'Evidence': '<Evidence>',
    'Concluding Statement': '<Concluding>',
    'Counterclaim': '<Counterclaim>',
    'Rebuttal': '<Rebuttal>',
    'Repeated': '',
}

mlm_token_map = {
    128000: '',
    128001: '',
    128002: '<Unannotated>',
    128003: '<Lead>',
    128004: '<Position>',
    128005: '<Claim>',
    128006: '<Evidence>',
    128007: '<Concluding>',
    128008: '<Counterclaim>',
    128009: '<Rebuttal>',
    -1: '',
}

count_dt = {
    0: '<Lead>',
    1: '<Position>',
    2: '<Claim>',
    3: '<Evidence>',
    4: '<Concluding>',
    5: '<Counterclaim>',
    6: '<Rebuttal>',
}


selected_cols = ['essay_id', 'full_text', 'prompt_name', 'score', 'kaggle_only']

pat_1 = '<(Unannotated|Lead|Position|Claim|Evidence|Concluding|Counterclaim|Rebuttal)>\n\n'
pat_2 = '\n\n<${1}>'

mlm_pat_1 = '<(Unannotated|Lead|Position|Claim|Evidence|Concluding|Counterclaim|Rebuttal)>'
mlm_pat_2 = '[MASK]'

mlm_pat_3 = '\[(MASK)\]\[PARAGRAPH\]'
mlm_pat_4 = '[PARAGRAPH][${1}]'

# %% [markdown]
# # create discourse training dataset

# %%
tp_df = pl.read_csv('/kaggle/input/lal-aes2-create-prompt-data/train_df_with_prompt.csv')
t_df = pl.read_csv('/kaggle/input/learning-agency-lab-automated-essay-scoring-2/train.csv')
p1_df = pl.read_csv('/kaggle/input/persuade-data/persuade_data/persuade_corpus_1.0.csv')
p2_df = pl.read_csv('/kaggle/input/persuade-data/persuade_data/persuade_2.0_human_scores_demo_id_github.csv')

# %%
t = p1_df.join(t_df, on='full_text').pivot(index='full_text', columns='discourse_type',values='discourse_type_num', aggregate_function='len').fill_null(0)
t = t.join(t_df, on='full_text').group_by('score').mean().sort('score').to_pandas().style.background_gradient()
t
# Out:
# <style type="text/css">
# #T_bb7d1_row0_col0, #T_bb7d1_row0_col2, #T_bb7d1_row0_col3, #T_bb7d1_row0_col4, #T_bb7d1_row0_col5, #T_bb7d1_row0_col6, #T_bb7d1_row0_col7, #T_bb7d1_row0_col8, #T_bb7d1_row0_col9 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_bb7d1_row1_col0 {
#   background-color: #dbdaeb;
#   color: #000000;
# }
# #T_bb7d1_row1_col2 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_bb7d1_row1_col3 {
#   background-color: #5ea0ca;
#   color: #f1f1f1;
# }
# #T_bb7d1_row1_col4 {
#   background-color: #034369;
#   color: #f1f1f1;
# }
# #T_bb7d1_row1_col5 {
#   background-color: #a1bbda;
#   color: #000000;
# }
# #T_bb7d1_row1_col6, #T_bb7d1_row3_col9 {
#   background-color: #c2cbe2;
#   color: #000000;
# }
# #T_bb7d1_row1_col7 {
#   background-color: #4c99c5;
#   color: #f1f1f1;
# }
# #T_bb7d1_row1_col8 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_bb7d1_row1_col9 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_bb7d1_row2_col0 {
#   background-color: #9cb9d9;
#   color: #000000;
# }
# #T_bb7d1_row2_col2 {
#   background-color: #81aed2;
#   color: #f1f1f1;
# }
# #T_bb7d1_row2_col3 {
#   background-color: #0568a3;
#   color: #f1f1f1;
# }
# #T_bb7d1_row2_col4, #T_bb7d1_row3_col4 {
#   background-color: #023f64;
#   color: #f1f1f1;
# }
# #T_bb7d1_row2_col5 {
#   background-color: #2685bb;
#   color: #f1f1f1;
# }
# #T_bb7d1_row2_col6 {
#   background-color: #3790c0;
#   color: #f1f1f1;
# }
# #T_bb7d1_row2_col7 {
#   background-color: #045f95;
#   color: #f1f1f1;
# }
# #T_bb7d1_row2_col8 {
#   background-color: #d2d3e7;
#   color: #000000;
# }
# #T_bb7d1_row2_col9 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_bb7d1_row3_col0 {
#   background-color: #4295c3;
#   color: #f1f1f1;
# }
# #T_bb7d1_row3_col2 {
#   background-color: #197db7;
#   color: #f1f1f1;
# }
# #T_bb7d1_row3_col3, #T_bb7d1_row4_col3, #T_bb7d1_row5_col0, #T_bb7d1_row5_col2, #T_bb7d1_row5_col4, #T_bb7d1_row5_col5, #T_bb7d1_row5_col6, #T_bb7d1_row5_col7, #T_bb7d1_row5_col8, #T_bb7d1_row5_col9 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_bb7d1_row3_col5 {
#   background-color: #045a8d;
#   color: #f1f1f1;
# }
# #T_bb7d1_row3_col6 {
#   background-color: #056caa;
#   color: #f1f1f1;
# }
# #T_bb7d1_row3_col7 {
#   background-color: #034b76;
#   color: #f1f1f1;
# }
# #T_bb7d1_row3_col8 {
#   background-color: #b9c6e0;
#   color: #000000;
# }
# #T_bb7d1_row4_col0 {
#   background-color: #0567a2;
#   color: #f1f1f1;
# }
# #T_bb7d1_row4_col2 {
#   background-color: #045483;
#   color: #f1f1f1;
# }
# #T_bb7d1_row4_col4 {
#   background-color: #023e62;
#   color: #f1f1f1;
# }
# #T_bb7d1_row4_col5 {
#   background-color: #03446a;
#   color: #f1f1f1;
# }
# #T_bb7d1_row4_col6 {
#   background-color: #045c90;
#   color: #f1f1f1;
# }
# #T_bb7d1_row4_col7 {
#   background-color: #034267;
#   color: #f1f1f1;
# }
# #T_bb7d1_row4_col8 {
#   background-color: #5c9fc9;
#   color: #f1f1f1;
# }
# #T_bb7d1_row4_col9 {
#   background-color: #6da6cd;
#   color: #f1f1f1;
# }
# #T_bb7d1_row5_col3 {
#   background-color: #04588a;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_bb7d1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bb7d1_level0_col0" class="col_heading level0 col0" >score</th>
#       <th id="T_bb7d1_level0_col1" class="col_heading level0 col1" >full_text</th>
#       <th id="T_bb7d1_level0_col2" class="col_heading level0 col2" >Lead</th>
#       <th id="T_bb7d1_level0_col3" class="col_heading level0 col3" >Unannotated</th>
#       <th id="T_bb7d1_level0_col4" class="col_heading level0 col4" >Position</th>
#       <th id="T_bb7d1_level0_col5" class="col_heading level0 col5" >Claim</th>
#       <th id="T_bb7d1_level0_col6" class="col_heading level0 col6" >Evidence</th>
#       <th id="T_bb7d1_level0_col7" class="col_heading level0 col7" >Concluding Statement</th>
#       <th id="T_bb7d1_level0_col8" class="col_heading level0 col8" >Counterclaim</th>
#       <th id="T_bb7d1_level0_col9" class="col_heading level0 col9" >Rebuttal</th>
#       <th id="T_bb7d1_level0_col10" class="col_heading level0 col10" >essay_id</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bb7d1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bb7d1_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_bb7d1_row0_col1" class="data row0 col1" >None</td>
#       <td id="T_bb7d1_row0_col2" class="data row0 col2" >0.312169</td>
#       <td id="T_bb7d1_row0_col3" class="data row0 col3" >0.515344</td>
#       <td id="T_bb7d1_row0_col4" class="data row0 col4" >0.612698</td>
#       <td id="T_bb7d1_row0_col5" class="data row0 col5" >0.675132</td>
#       <td id="T_bb7d1_row0_col6" class="data row0 col6" >1.601058</td>
#       <td id="T_bb7d1_row0_col7" class="data row0 col7" >0.344974</td>
#       <td id="T_bb7d1_row0_col8" class="data row0 col8" >0.065608</td>
#       <td id="T_bb7d1_row0_col9" class="data row0 col9" >0.022222</td>
#       <td id="T_bb7d1_row0_col10" class="data row0 col10" >None</td>
#     </tr>
#     <tr>
#       <th id="T_bb7d1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_bb7d1_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_bb7d1_row1_col1" class="data row1 col1" >None</td>
#       <td id="T_bb7d1_row1_col2" class="data row1 col2" >0.423491</td>
#       <td id="T_bb7d1_row1_col3" class="data row1 col3" >1.100754</td>
#       <td id="T_bb7d1_row1_col4" class="data row1 col4" >0.997037</td>
#       <td id="T_bb7d1_row1_col5" class="data row1 col5" >2.054688</td>
#       <td id="T_bb7d1_row1_col6" class="data row1 col6" >2.255388</td>
#       <td id="T_bb7d1_row1_col7" class="data row1 col7" >0.734375</td>
#       <td id="T_bb7d1_row1_col8" class="data row1 col8" >0.207974</td>
#       <td id="T_bb7d1_row1_col9" class="data row1 col9" >0.116110</td>
#       <td id="T_bb7d1_row1_col10" class="data row1 col10" >None</td>
#     </tr>
#     <tr>
#       <th id="T_bb7d1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_bb7d1_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_bb7d1_row2_col1" class="data row2 col1" >None</td>
#       <td id="T_bb7d1_row2_col2" class="data row2 col2" >0.566529</td>
#       <td id="T_bb7d1_row2_col3" class="data row2 col3" >1.370306</td>
#       <td id="T_bb7d1_row2_col4" class="data row2 col4" >1.003039</td>
#       <td id="T_bb7d1_row2_col5" class="data row2 col5" >3.051226</td>
#       <td id="T_bb7d1_row2_col6" class="data row2 col6" >2.997395</td>
#       <td id="T_bb7d1_row2_col7" class="data row2 col7" >0.912090</td>
#       <td id="T_bb7d1_row2_col8" class="data row2 col8" >0.316258</td>
#       <td id="T_bb7d1_row2_col9" class="data row2 col9" >0.215759</td>
#       <td id="T_bb7d1_row2_col10" class="data row2 col10" >None</td>
#     </tr>
#     <tr>
#       <th id="T_bb7d1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_bb7d1_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_bb7d1_row3_col1" class="data row3 col1" >None</td>
#       <td id="T_bb7d1_row3_col2" class="data row3 col2" >0.692425</td>
#       <td id="T_bb7d1_row3_col3" class="data row3 col3" >1.588123</td>
#       <td id="T_bb7d1_row3_col4" class="data row3 col4" >1.002665</td>
#       <td id="T_bb7d1_row3_col5" class="data row3 col5" >3.778455</td>
#       <td id="T_bb7d1_row3_col6" class="data row3 col6" >3.323944</td>
#       <td id="T_bb7d1_row3_col7" class="data row3 col7" >0.966121</td>
#       <td id="T_bb7d1_row3_col8" class="data row3 col8" >0.398934</td>
#       <td id="T_bb7d1_row3_col9" class="data row3 col9" >0.323944</td>
#       <td id="T_bb7d1_row3_col10" class="data row3 col10" >None</td>
#     </tr>
#     <tr>
#       <th id="T_bb7d1_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_bb7d1_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_bb7d1_row4_col1" class="data row4 col1" >None</td>
#       <td id="T_bb7d1_row4_col2" class="data row4 col2" >0.802145</td>
#       <td id="T_bb7d1_row4_col3" class="data row4 col3" >1.589988</td>
#       <td id="T_bb7d1_row4_col4" class="data row4 col4" >1.004768</td>
#       <td id="T_bb7d1_row4_col5" class="data row4 col5" >4.070322</td>
#       <td id="T_bb7d1_row4_col6" class="data row4 col6" >3.526818</td>
#       <td id="T_bb7d1_row4_col7" class="data row4 col7" >0.990465</td>
#       <td id="T_bb7

# %%
ol_df = p1_df.join(t_df, on='full_text').join(p2_df.select(['essay_id_comp', 'full_text', 'prompt_name']), on='full_text')
ol_df = ol_df.select(['essay_id', 'full_text', 'discourse_start', 'discourse_end', 'discourse_text', 'discourse_type', 'score', 'prompt_name'])
ol_df = ol_df.filter(pl.col('discourse_type') != "Unannotated")
ol_df
# Out:
# shape: (109_504, 8)
# ┌──────────┬─────────────┬─────────────┬────────────┬────────────┬────────────┬───────┬────────────┐
# │ essay_id ┆ full_text   ┆ discourse_s ┆ discourse_ ┆ discourse_ ┆ discourse_ ┆ score ┆ prompt_nam │
# │ ---      ┆ ---         ┆ tart        ┆ end        ┆ text       ┆ type       ┆ ---   ┆ e          │
# │ str      ┆ str         ┆ ---         ┆ ---        ┆ ---        ┆ ---        ┆ i64   ┆ ---        │
# │          ┆             ┆ i64         ┆ i64        ┆ str        ┆ str        ┆       ┆ str        │
# ╞══════════╪═════════════╪═════════════╪════════════╪════════════╪════════════╪═══════╪════════════╡
# │ d5b6859  ┆ Cars have   ┆ 0           ┆ 163        ┆ Cars have  ┆ Lead       ┆ 5     ┆ Car-free   │
# │          ┆ been around ┆             ┆            ┆ been       ┆            ┆       ┆ cities     │
# │          ┆ for awhile… ┆             ┆            ┆ around for ┆            ┆       ┆            │
# │          ┆             ┆             ┆            ┆ awhile…    ┆            ┆       ┆            │
# │ d5b6859  ┆ Cars have   ┆ 168         ┆ 209        ┆ there are  ┆ Position   ┆ 5     ┆ Car-free   │
# │          ┆ been around ┆             ┆            ┆ many       ┆            ┆       ┆ cities     │
# │          ┆ for awhile… ┆             ┆            ┆ advantages ┆            ┆       ┆            │
# │          ┆             ┆             ┆            ┆ to les…    ┆            ┆       ┆            │
# │ d5b6859  ┆ Cars have   ┆ 217         ┆ 250        ┆ improving  ┆ Claim      ┆ 5     ┆ Car-free   │
# │          ┆ been around ┆             ┆            ┆ our cities ┆            ┆       ┆ cities     │
# │          ┆ for awhile… ┆             ┆            ┆ and        ┆            ┆       ┆            │
# │          ┆             ┆             ┆            ┆ suburbs…   ┆            ┆       ┆            │
# │ d5b6859  ┆ Cars have   ┆ 251         ┆ 268        ┆ improving  ┆ Claim      ┆ 5     ┆ Car-free   │
# │          ┆ been around ┆             ┆            ┆ safety,    ┆            ┆       ┆ cities     │
# │          ┆ for awhile… ┆             ┆            ┆            ┆            ┆       ┆            │
# │ d5b6859  ┆ Cars have   ┆ 273         ┆ 294        ┆ decreasing ┆ Claim      ┆ 5     ┆ Car-free   │
# │          ┆ been around ┆             ┆            ┆ pollution. ┆            ┆       ┆ cities     │
# │          ┆ for awhile… ┆             ┆            ┆            ┆            ┆       ┆            │
# │ …        ┆ …           ┆ …           ┆ …          ┆ …          ┆ …          ┆ …     ┆ …          │
# │ ac8fa95  ┆ This goes   ┆ 204         ┆ 439        ┆ Because    ┆ Evidence   ┆ 2     ┆ Does the   │
# │          ┆ out to the  ┆             ┆            ┆ whats the  ┆            ┆       ┆ electoral  │
# │          ┆ senator of  ┆             ┆            ┆ point of   ┆            ┆       ┆ college    │
# │          ┆ …           ┆             ┆            ┆ all o…     ┆            ┆       ┆ work?      │
# │ ac8fa95  ┆ This goes   ┆ 440         ┆ 822        ┆ Now that   ┆ Evidence   ┆ 2     ┆ Does the   │
# │          ┆ out to the  ┆             ┆            ┆ I've read  ┆            ┆       ┆ electoral  │
# │          ┆ senator of  ┆             ┆            ┆ it we      ┆            ┆       ┆ college    │
# │          ┆ …           ┆             ┆            ┆ don't e…   ┆            ┆       ┆ work?      │
# │ ac8fa95  ┆ This goes   ┆ 823         ┆ 884        ┆ Can voters ┆ Claim      ┆ 2     ┆ Does the   │
# │          ┆ out to the  ┆             ┆            ┆ control    ┆            ┆       ┆ electoral  │
# │          ┆ senator of  ┆             ┆            ┆ whom their ┆            ┆       ┆ college    │
# │          ┆ …           ┆             ┆            ┆ el…        ┆            ┆       ┆ work?      │
# │ ac8fa95  ┆ This goes   ┆ 885         ┆ 980        ┆ Do voters  ┆ Claim      ┆ 2     ┆ Does the   │
# │          ┆ out to the  ┆             ┆            ┆ sometimes  ┆            ┆       ┆ electoral  │
# │          ┆ senator of  ┆             ┆            ┆ get        ┆            ┆       ┆ college    │
# │          ┆ …           ┆             ┆            ┆ confused…  ┆            ┆       ┆ work?      │
# │ ac8fa95  ┆ This goes   ┆ 981         ┆ 1320       ┆ At the     ┆ Concluding ┆ 2     ┆ Does the   │
# │          ┆ out to the  ┆             ┆            ┆ most basic ┆ Statement  ┆       ┆ electoral  │
# │          ┆ senator of  ┆             ┆            ┆ level the  ┆            ┆       ┆ college    │
# │          ┆ …           ┆             ┆            ┆ elec…      ┆            ┆       ┆ work?      │
# └──────────┴─────────────┴─────────────┴────────────┴────────────┴────────────┴───────┴────────────┘

# %% [markdown]
# ## nko_sen contains all DT except unannotated

# %%
nko_sen = ol_df.with_columns(pl.col('discourse_text').str.strip_chars()).filter((pl.col('discourse_text') != '')).filter(pl.col('discourse_text') != '.')
nko_sen = nko_sen.with_columns(pl.col('discourse_type').replace(token_dt_map).alias('s_token'))
nko_sen
# Out:
# shape: (109_504, 9)
# ┌──────────┬────────────┬────────────┬────────────┬───┬────────────┬───────┬───────────┬───────────┐
# │ essay_id ┆ full_text  ┆ discourse_ ┆ discourse_ ┆ … ┆ discourse_ ┆ score ┆ prompt_na ┆ s_token   │
# │ ---      ┆ ---        ┆ start      ┆ end        ┆   ┆ type       ┆ ---   ┆ me        ┆ ---       │
# │ str      ┆ str        ┆ ---        ┆ ---        ┆   ┆ ---        ┆ i64   ┆ ---       ┆ str       │
# │          ┆            ┆ i64        ┆ i64        ┆   ┆ str        ┆       ┆ str       ┆           │
# ╞══════════╪════════════╪════════════╪════════════╪═══╪════════════╪═══════╪═══════════╪═══════════╡
# │ d5b6859  ┆ Cars have  ┆ 0          ┆ 163        ┆ … ┆ Lead       ┆ 5     ┆ Car-free  ┆ <Lead>    │
# │          ┆ been       ┆            ┆            ┆   ┆            ┆       ┆ cities    ┆           │
# │          ┆ around for ┆            ┆            ┆   ┆            ┆       ┆           ┆           │
# │          ┆ awhile…    ┆            ┆            ┆   ┆            ┆       ┆           ┆           │
# │ d5b6859  ┆ Cars have  ┆ 168        ┆ 209        ┆ … ┆ Position   ┆ 5     ┆ Car-free  ┆ <Position │
# │          ┆ been       ┆            ┆            ┆   ┆            ┆       ┆ cities    ┆ >         │
# │          ┆ around for ┆            ┆            ┆   ┆            ┆       ┆           ┆           │
# │          ┆ awhile…    ┆            ┆            ┆   ┆            ┆       ┆           ┆           │
# │ d5b6859  ┆ Cars have  ┆ 217        ┆ 250        ┆ … ┆ Claim      ┆ 5     ┆ Car-free  ┆ <Claim>   │
# │          ┆ been       ┆            ┆            ┆   ┆            ┆       ┆ cities    ┆           │
# │          ┆ around for ┆            ┆            ┆   ┆            ┆       ┆           ┆           │
# │          ┆ awhile…    ┆            ┆            ┆   ┆            ┆       ┆           ┆           │
# │ d5b6859  ┆ Cars have  ┆ 251        ┆ 268        ┆ … ┆ Claim      ┆ 5     ┆ Car-free  ┆ <Claim>   │
# │          ┆ been       ┆            ┆            ┆   ┆            ┆       ┆ cities    ┆           │
# │          ┆ around for ┆            ┆            ┆   ┆            ┆       ┆           ┆           │
# │          ┆ awhile…    ┆            ┆            ┆   ┆            ┆       ┆           ┆           │
# │ d5b6859  ┆ Cars have  ┆ 273        ┆ 294        ┆ … ┆ Claim      ┆ 5     ┆ Car-free  ┆ <Claim>   │
# │          ┆ been       ┆            ┆            ┆   ┆            ┆       ┆ cities    ┆           │
# │          ┆ around for ┆            ┆            ┆   ┆            ┆       ┆           ┆           │
# │          ┆ awhile…    ┆            ┆            ┆   ┆            ┆       ┆           ┆           │
# │ …        ┆ …          ┆ …          ┆ …          ┆ … ┆ …          ┆ …     ┆ …         ┆ …         │
# │ ac8fa95  ┆ This goes  ┆ 204        ┆ 439        ┆ … ┆ Evidence   ┆ 2     ┆ Does the  ┆ <Evidence │
# │          ┆ out to the ┆            ┆            ┆   ┆            ┆       ┆ electoral ┆ >         │
# │          ┆ senator of ┆            ┆            ┆   ┆            ┆       ┆ college   ┆           │
# │          ┆ …          ┆            ┆            ┆   ┆            ┆       ┆ work?     ┆           │
# │ ac8fa95  ┆ This goes  ┆ 440        ┆ 822        ┆ … ┆ Evidence   ┆ 2     ┆ Does the  ┆ <Evidence │
# │          ┆ out to the ┆            ┆            ┆   ┆            ┆       ┆ electoral ┆ >         │
# │          ┆ senator of ┆            ┆            ┆   ┆            ┆       ┆ college   ┆           │
# │          ┆ …          ┆            ┆            ┆   ┆            ┆       ┆ work?     ┆           │
# │ ac8fa95  ┆ This goes  ┆ 823        ┆ 884        ┆ … ┆ Claim      ┆ 2     ┆ Does the  ┆ <Claim>   │
# │          ┆ out to the ┆            ┆            ┆   ┆            ┆       ┆ electoral ┆           │
# │          ┆ senator of ┆            ┆            ┆   ┆            ┆       ┆ college   ┆           │
# │          ┆ …          ┆            ┆            ┆   ┆            ┆       ┆ work?     ┆           │
# │ ac8fa95  ┆ This goes  ┆ 885        ┆ 980        ┆ … ┆ Claim      ┆ 2     ┆ Does the  ┆ <Claim>   │
# │          ┆ out to the ┆            ┆            ┆   ┆            ┆       ┆ electoral ┆           │
# │          ┆ senator of ┆            ┆            ┆   ┆            ┆       ┆ college   ┆           │
# │          ┆ …          ┆            ┆            ┆   ┆            ┆       ┆ work?     ┆           │
# │ ac8fa95  ┆ This goes  ┆ 981        ┆ 1320       ┆ … ┆ Concluding ┆ 2     ┆ Does the  ┆ <Concludi │
# │          ┆ out to the ┆            ┆            ┆   ┆ Statement  ┆       ┆ electoral ┆ ng>       │
# │          ┆ senator of ┆            ┆            ┆   ┆            ┆       ┆ college   ┆           │
# │          ┆ …          ┆            ┆            ┆   ┆            ┆       ┆ work?     ┆           │
# └──────────┴────────────┴────────────┴────────────┴───┴────────────┴───────┴───────────┴───────────┘

# %%
essay_id_list = []
tokened_text = []
for name, data in nko_sen.group_by(['essay_id', 'full_text'], maintain_order=True):
    essay_id = name[0]
    full_text = name[1]
    dt_len = data.shape[0]
    offset = 0
    n_offset = 0
    for i in range(dt_len):
        
        start_pos = data['discourse_start'][i]
        s_token = data['s_token'][i]
        n_offset = full_text[:start_pos + offset].count('\n')
        temp_offset = 0

        if (n_offset % 2 == 1):
            temp_offset += 1
            
        if full_text[start_pos + offset:][:2] == '\n\n':
            temp_offset += 2
            
        if (full_text[start_pos + offset:][0] == ' '):
            offset += 1
            
        if full_text[start_pos + offset:][0] == '.':
            offset += 1
            
        full_text = full_text[:start_pos + offset + temp_offset] + s_token + full_text[start_pos + offset + temp_offset:]
        offset += len(s_token)
            
    essay_id_list.append(essay_id)
    tokened_text.append(full_text)

# %%
nko_sen = tp_df.join(pl.DataFrame({'essay_id': essay_id_list, 'tokened_text': tokened_text}), on='essay_id', how='inner')
nko_sen
# Out:
# shape: (12_871, 6)
# ┌──────────┬─────────────────────┬─────────────────────┬───────┬─────────────┬─────────────────────┐
# │ essay_id ┆ full_text           ┆ prompt_name         ┆ score ┆ kaggle_only ┆ tokened_text        │
# │ ---      ┆ ---                 ┆ ---                 ┆ ---   ┆ ---         ┆ ---                 │
# │ str      ┆ str                 ┆ str                 ┆ i64   ┆ bool        ┆ str                 │
# ╞══════════╪═════════════════════╪═════════════════════╪═══════╪═════════════╪═════════════════════╡
# │ 000d118  ┆ Many people have    ┆ Car-free cities     ┆ 3     ┆ false       ┆ <Lead>Many people   │
# │          ┆ car where they …    ┆                     ┆       ┆             ┆ have car where…     │
# │ 002ba53  ┆ Dear, State Senator ┆ Does the electoral  ┆ 3     ┆ false       ┆ Dear, State Senator │
# │          ┆                     ┆ college work?       ┆       ┆             ┆                     │
# │          ┆ This is a l…        ┆                     ┆       ┆             ┆ <Position>T…        │
# │ 0030e86  ┆ If I were to choose ┆ Does the electoral  ┆ 4     ┆ false       ┆ <Position>If I were │
# │          ┆ between keep…       ┆ college work?       ┆       ┆             ┆ to choose be…       │
# │ 0033bf4  ┆ What is the         ┆ "A Cowboy Who Rode  ┆ 3     ┆ false       ┆ <Lead>What is the   │
# │          ┆ Seagoing Cowboys    ┆ the Waves"          ┆       ┆             ┆ Seagoing Cowbo…     │
# │          ┆ pro…                ┆                     ┆       ┆             ┆                     │
# │ 0036253  ┆ The challenge of    ┆ Exploring Venus     ┆ 2     ┆ false       ┆ The challenge of    │
# │          ┆ exploring Venus…    ┆                     ┆       ┆             ┆ exploring Venus…    │
# │ …        ┆ …                   ┆ …                   ┆ …     ┆ …           ┆ …                   │
# │ ffc11a8  ┆ You should join the ┆ "A Cowboy Who Rode  ┆ 3     ┆ false       ┆ <Position>You       │
# │          ┆ Seagoing Cow…       ┆ the Waves"          ┆       ┆             ┆ should join the Se… │
# │ ffc9095  ┆ Venus, an           ┆ Exploring Venus     ┆ 3     ┆ false       ┆ <Lead>Venus, an     │
# │          ┆ extraordinary       ┆                     ┆       ┆             ┆ extraordinary pl…   │
# │          ┆ planet b…           ┆                     ┆       ┆             ┆                     │
# │ ffddf1f  ┆ Technology has      ┆ Facial action       ┆ 4     ┆ false       ┆ <Lead>Technology    │
# │          ┆ changed a lot of …  ┆ coding system       ┆       ┆             ┆ has changed a l…    │
# │ fff016d  ┆ If you don't like   ┆ "A Cowboy Who Rode  ┆ 2     ┆ false       ┆ <Lead>If you don't  │
# │          ┆ sitting around…     ┆ the Waves"          ┆       ┆             ┆ like sitting …      │
# │ fffb49b  ┆ In "The Challenge   ┆ Exploring Venus     ┆ 1     ┆ false       ┆ <Position>In "The   │
# │          ┆ of Exporing Ve…     ┆                     ┆       ┆             ┆ Challenge of E…     │
# └──────────┴─────────────────────┴─────────────────────┴───────┴─────────────┴─────────────────────┘

# %% [markdown]
# ## Non-Overlapping Persuade2.0

# %%
nol_df = p1_df.join(t_df, on='full_text', how='anti').join(p2_df.select(['essay_id_comp', 'full_text', 'prompt_name', 'holistic_essay_score']), on='full_text')
nol_df = nol_df.rename({'essay_id_comp': 'essay_id', 'holistic_essay_score': 'score'})
nol_df = nol_df.select(['essay_id', 'full_text', 'discourse_start', 'discourse_end', 'discourse_text', 'discourse_type', 'score', 'prompt_name'])
nol_df = nol_df.filter(pl.col('discourse_type') != "Unannotated")
nol_df
# Out:
# shape: (128_469, 8)
# ┌────────────┬────────────┬────────────┬────────────┬────────────┬────────────┬───────┬────────────┐
# │ essay_id   ┆ full_text  ┆ discourse_ ┆ discourse_ ┆ discourse_ ┆ discourse_ ┆ score ┆ prompt_nam │
# │ ---        ┆ ---        ┆ start      ┆ end        ┆ text       ┆ type       ┆ ---   ┆ e          │
# │ str        ┆ str        ┆ ---        ┆ ---        ┆ ---        ┆ ---        ┆ i64   ┆ ---        │
# │            ┆            ┆ i64        ┆ i64        ┆ str        ┆ str        ┆       ┆ str        │
# ╞════════════╪════════════╪════════════╪════════════╪════════════╪════════════╪═══════╪════════════╡
# │ 423A1CA112 ┆ Phones     ┆ 8          ┆ 229        ┆ Modern     ┆ Lead       ┆ 3     ┆ Phones and │
# │ E2         ┆            ┆            ┆            ┆ humans     ┆            ┆       ┆ driving    │
# │            ┆ Modern     ┆            ┆            ┆ today are  ┆            ┆       ┆            │
# │            ┆ humans     ┆            ┆            ┆ always o…  ┆            ┆       ┆            │
# │            ┆ today are  ┆            ┆            ┆            ┆            ┆       ┆            │
# │            ┆ …          ┆            ┆            ┆            ┆            ┆       ┆            │
# │ 423A1CA112 ┆ Phones     ┆ 230        ┆ 312        ┆ They are   ┆ Position   ┆ 3     ┆ Phones and │
# │ E2         ┆            ┆            ┆            ┆ some       ┆            ┆       ┆ driving    │
# │            ┆ Modern     ┆            ┆            ┆ really bad ┆            ┆       ┆            │
# │            ┆ humans     ┆            ┆            ┆ consequ…   ┆            ┆       ┆            │
# │            ┆ today are  ┆            ┆            ┆            ┆            ┆       ┆            │
# │            ┆ …          ┆            ┆            ┆            ┆            ┆       ┆            │
# │ 423A1CA112 ┆ Phones     ┆ 313        ┆ 400        ┆ Some       ┆ Evidence   ┆ 3     ┆ Phones and │
# │ E2         ┆            ┆            ┆            ┆ certain    ┆            ┆       ┆ driving    │
# │            ┆ Modern     ┆            ┆            ┆ areas in   ┆            ┆       ┆            │
# │            ┆ humans     ┆            ┆            ┆ the        ┆            ┆       ┆            │
# │            ┆ today are  ┆            ┆            ┆ United…    ┆            ┆       ┆            │
# │            ┆ …          ┆            ┆            ┆            ┆            ┆       ┆            │
# │ 423A1CA112 ┆ Phones     ┆ 401        ┆ 756        ┆ When       ┆ Evidence   ┆ 3     ┆ Phones and │
# │ E2         ┆            ┆            ┆            ┆ people     ┆            ┆       ┆ driving    │
# │            ┆ Modern     ┆            ┆            ┆ have       ┆            ┆       ┆            │
# │            ┆ humans     ┆            ┆            ┆ phones,    ┆            ┆       ┆            │
# │            ┆ today are  ┆            ┆            ┆ they kn…   ┆            ┆       ┆            │
# │            ┆ …          ┆            ┆            ┆            ┆            ┆       ┆            │
# │ 423A1CA112 ┆ Phones     ┆ 757        ┆ 884        ┆ Driving is ┆ Claim      ┆ 3     ┆ Phones and │
# │ E2         ┆            ┆            ┆            ┆ one of the ┆            ┆       ┆ driving    │
# │            ┆ Modern     ┆            ┆            ┆ way how    ┆            ┆       ┆            │
# │            ┆ humans     ┆            ┆            ┆ to…        ┆            ┆       ┆            │
# │            ┆ today are  ┆            ┆            ┆            ┆            ┆       ┆            │
# │            ┆ …          ┆            ┆            ┆            ┆            ┆       ┆            │
# │ …          ┆ …          ┆ …          ┆ …          ┆ …          ┆ …          ┆ …     ┆ …          │
# │ DF920E0A73 ┆ Have you   ┆ 513        ┆ 558        ┆ it informs ┆ Claim      ┆ 4     ┆ Seeking    │
# │ 37         ┆ ever asked ┆            ┆            ┆ you about  ┆            ┆       ┆ multiple   │
# │            ┆ more than  ┆            ┆            ┆ what other ┆            ┆       ┆ opinions   │
# │            ┆ on…        ┆            ┆            ┆ …          ┆            ┆       ┆            │
# │ DF920E0A73 ┆ Have you   ┆ 610        ┆ 1569       ┆ One        ┆ Evidence   ┆ 4     ┆ Seeking    │
# │ 37         ┆ ever asked ┆            ┆            ┆ opinion of ┆            ┆       ┆ multiple   │
# │            ┆ more than  ┆            ┆            ┆ a person   ┆            ┆       ┆ opinions   │
# │            ┆ on…        ┆            ┆            ┆ might de…  ┆            ┆       ┆            │
# │ DF920E0A73 ┆ Have you   ┆ 1621       ┆ 2395       ┆ One person ┆ Evidence   ┆ 4     ┆ Seeking    │
# │ 37         ┆ ever asked ┆            ┆            ┆ can change ┆            ┆       ┆ multiple   │
# │            ┆ more than  ┆            ┆            ┆ your       ┆            ┆       ┆ opinions   │
# │            ┆ on…        ┆            ┆            ┆ optio…     ┆            ┆       ┆            │
# │ DF920E0A73 ┆ Have you   ┆ 2452       ┆ 3263       ┆ Having     ┆ Evidence   ┆ 4     ┆ Seeking    │
# │ 37         ┆ ever asked ┆            ┆            ┆ more than  ┆            ┆       ┆ multiple   │
# │            ┆ more than  ┆            ┆            ┆ one        ┆            ┆       ┆ opinions   │
# │            ┆ on…        ┆            ┆            ┆ person's   ┆            ┆       ┆            │
# │            ┆            ┆            ┆            ┆ op…        ┆            ┆       ┆            │
# │ DF920E0A73 ┆ Have you   ┆ 3280       ┆ 3626       ┆ finding    ┆ Concluding ┆ 4     ┆ Seeking    │
# │ 37         ┆ ever asked ┆            ┆            ┆ more than  ┆ Statement  ┆       ┆ multiple   │
# │            ┆ more than  ┆            ┆            ┆ one        ┆            ┆       ┆ opinions   │
# │            ┆ on…        ┆            ┆            ┆ persons    ┆            ┆       ┆            │
# │            ┆            ┆            ┆            ┆ vi…        ┆            ┆       ┆            │
# └────────────┴────────────┴────────────┴────────────┴────────────┴────────────┴───────┴────────────┘

# %%
nol_sen_ = nol_df.with_columns(pl.col('discourse_text').str.strip_chars()).filter((pl.col('discourse_text') != '')).filter(pl.col('discourse_text') != '.')
nol_sen_ = nol_sen_.with_columns(pl.col('discourse_type').replace(token_dt_map).alias('s_token'))
nol_sen_
# Out:
# shape: (128_469, 9)
# ┌────────────┬────────────┬────────────┬───────────┬───┬───────────┬───────┬───────────┬───────────┐
# │ essay_id   ┆ full_text  ┆ discourse_ ┆ discourse ┆ … ┆ discourse ┆ score ┆ prompt_na ┆ s_token   │
# │ ---        ┆ ---        ┆ start      ┆ _end      ┆   ┆ _type     ┆ ---   ┆ me        ┆ ---       │
# │ str        ┆ str        ┆ ---        ┆ ---       ┆   ┆ ---       ┆ i64   ┆ ---       ┆ str       │
# │            ┆            ┆ i64        ┆ i64       ┆   ┆ str       ┆       ┆ str       ┆           │
# ╞════════════╪════════════╪════════════╪═══════════╪═══╪═══════════╪═══════╪═══════════╪═══════════╡
# │ 423A1CA112 ┆ Phones     ┆ 8          ┆ 229       ┆ … ┆ Lead      ┆ 3     ┆ Phones    ┆ <Lead>    │
# │ E2         ┆            ┆            ┆           ┆   ┆           ┆       ┆ and       ┆           │
# │            ┆ Modern     ┆            ┆           ┆   ┆           ┆       ┆ driving   ┆           │
# │            ┆ humans     ┆            ┆           ┆   ┆           ┆       ┆           ┆           │
# │            ┆ today are  ┆            ┆           ┆   ┆           ┆       ┆           ┆           │
# │            ┆ …          ┆            ┆           ┆   ┆           ┆       ┆           ┆           │
# │ 423A1CA112 ┆ Phones     ┆ 230        ┆ 312       ┆ … ┆ Position  ┆ 3     ┆ Phones    ┆ <Position │
# │ E2         ┆            ┆            ┆           ┆   ┆           ┆       ┆ and       ┆ >         │
# │            ┆ Modern     ┆            ┆           ┆   ┆           ┆       ┆ driving   ┆           │
# │            ┆ humans     ┆            ┆           ┆   ┆           ┆       ┆           ┆           │
# │            ┆ today are  ┆            ┆           ┆   ┆           ┆       ┆           ┆           │
# │            ┆ …          ┆            ┆           ┆   ┆           ┆       ┆           ┆           │
# │ 423A1CA112 ┆ Phones     ┆ 313        ┆ 400       ┆ … ┆ Evidence  ┆ 3     ┆ Phones    ┆ <Evidence │
# │ E2         ┆            ┆            ┆           ┆   ┆           ┆       ┆ and       ┆ >         │
# │            ┆ Modern     ┆            ┆           ┆   ┆           ┆       ┆ driving   ┆           │
# │            ┆ humans     ┆            ┆           ┆   ┆           ┆       ┆           ┆           │
# │            ┆ today are  ┆            ┆           ┆   ┆           ┆       ┆           ┆           │
# │            ┆ …          ┆            ┆           ┆   ┆           ┆       ┆           ┆           │
# │ 423A1CA112 ┆ Phones     ┆ 401        ┆ 756       ┆ … ┆ Evidence  ┆ 3     ┆ Phones    ┆ <Evidence │
# │ E2         ┆            ┆            ┆           ┆   ┆           ┆       ┆ and       ┆ >         │
# │            ┆ Modern     ┆            ┆           ┆   ┆           ┆       ┆ driving   ┆           │
# │            ┆ humans     ┆            ┆           ┆   ┆           ┆       ┆           ┆           │
# │            ┆ today are  ┆            ┆           ┆   ┆           ┆       ┆           ┆           │
# │            ┆ …          ┆            ┆           ┆   ┆           ┆       ┆           ┆           │
# │ 423A1CA112 ┆ Phones     ┆ 757        ┆ 884       ┆ … ┆ Claim     ┆ 3     ┆ Phones    ┆ <Claim>   │
# │ E2         ┆            ┆            ┆           ┆   ┆           ┆       ┆ and       ┆           │
# │            ┆ Modern     ┆            ┆           ┆   ┆           ┆       ┆ driving   ┆           │
# │            ┆ humans     ┆            ┆           ┆   ┆           ┆       ┆           ┆           │
# │            ┆ today are  ┆            ┆           ┆   ┆           ┆       ┆           ┆           │
# │            ┆ …          ┆            ┆           ┆   ┆           ┆       ┆           ┆           │
# │ …          ┆ …          ┆ …          ┆ …         ┆ … ┆ …         ┆ …     ┆ …         ┆ …         │
# │ DF920E0A73 ┆ Have you   ┆ 513        ┆ 558       ┆ … ┆ Claim     ┆ 4     ┆ Seeking   ┆ <Claim>   │
# │ 37         ┆ ever asked ┆            ┆           ┆   ┆           ┆       ┆ multiple  ┆           │
# │            ┆ more than  ┆            ┆           ┆   ┆           ┆       ┆ opinions  ┆           │
# │            ┆ on…        ┆            ┆           ┆   ┆           ┆       ┆           ┆           │
# │ DF920E0A73 ┆ Have you   ┆ 610        ┆ 1569      ┆ … ┆ Evidence  ┆ 4     ┆ Seeking   ┆ <Evidence │
# │ 37         ┆ ever asked ┆            ┆           ┆   ┆           ┆       ┆ multiple  ┆ >         │
# │            ┆ more than  ┆            ┆           ┆   ┆           ┆       ┆ opinions  ┆           │
# │            ┆ on…        ┆            ┆           ┆   ┆           ┆       ┆           ┆           │
# │ DF920E0A73 ┆ Have you   ┆ 1621       ┆ 2395      ┆ … ┆ Evidence  ┆ 4     ┆ Seeking   ┆ <Evidence │
# │ 37         ┆ ever asked ┆            ┆           ┆   ┆           ┆       ┆ multiple  ┆ >         │
# │            ┆ more than  ┆            ┆           ┆   ┆           ┆       ┆ opinions  ┆           │
# │            ┆ on…        ┆            ┆           ┆   ┆           ┆       ┆           ┆           │
# │ DF920E0A73 ┆ Have you   ┆ 2452       ┆ 3263      ┆ … ┆ Evidence  ┆ 4     ┆ Seeking   ┆ <Evidence │
# │ 37         ┆ ever asked ┆            ┆           ┆   ┆           ┆       ┆ multiple  ┆ >         │
# │            ┆ more than  ┆            ┆           ┆   ┆           ┆       ┆ opinions  ┆           │
# │            ┆ on…        ┆            ┆           ┆   ┆           ┆       ┆           ┆           │
# │ DF920E0A73 ┆ Have you   ┆ 3280       ┆ 3626      ┆ … ┆ Concludin ┆ 4     ┆ Seeking   ┆ <Concludi │
# │ 37         ┆ ever asked ┆            ┆           ┆   ┆ g         ┆       ┆ multiple  ┆ ng>       │
# │            ┆ more than  ┆            ┆           ┆   ┆ Statement ┆       ┆ opinions  ┆           │
# │            ┆ on…        ┆            ┆           ┆   ┆           ┆       ┆           ┆           │
# └────────────┴────────────┴────────────┴───────────┴───┴───────────┴───────┴───────────┴───────────┘

# %%
essay_id_list = []
tokened_text = []
for name, data in nol_sen_.group_by(['essay_id', 'full_text'], maintain_order=True):
    essay_id = name[0]
    full_text = name[1]
    dt_len = data.shape[0]
    offset = 0
    n_offset = 0
    for i in range(dt_len):
        
        start_pos = data['discourse_start'][i]
        s_token = data['s_token'][i]
        n_offset = full_text[:start_pos + offset].count('\n')
        temp_offset = 0

        if (n_offset % 2 == 1):
            temp_offset += 1
            
        if full_text[start_pos + offset:][:2] == '\n\n':
            temp_offset += 2
            
        if (full_text[start_pos + offset:][0] == ' '):
            offset += 1
            
        if full_text[start_pos + offset:][0] == '.':
            offset += 1
            
        full_text = full_text[:start_pos + offset + temp_offset] + s_token + full_text[start_pos + offset + temp_offset:]
        offset += len(s_token)
            
    essay_id_list.append(essay_id)
    tokened_text.append(full_text)

# %%
nol_sen = nol_sen_.join(pl.DataFrame({'essay_id': essay_id_list, 'tokened_text': tokened_text}), on='essay_id')
nol_sen = nol_sen.with_columns(kaggle_only=None)
nol_sen = nol_sen.select(['essay_id', 'full_text', 'prompt_name', 'score', 'kaggle_only', 'tokened_text']).unique().sort('essay_id')
nol_sen
# Out:
# shape: (13_125, 6)
# ┌──────────────┬────────────────────┬────────────────────┬───────┬─────────────┬───────────────────┐
# │ essay_id     ┆ full_text          ┆ prompt_name        ┆ score ┆ kaggle_only ┆ tokened_text      │
# │ ---          ┆ ---                ┆ ---                ┆ ---   ┆ ---         ┆ ---               │
# │ str          ┆ str                ┆ str                ┆ i64   ┆ null        ┆ str               │
# ╞══════════════╪════════════════════╪════════════════════╪═══════╪═════════════╪═══════════════════╡
# │ 000A58BC095E ┆ To Whom It May     ┆ Community service  ┆ 2     ┆ null        ┆ To Whom It May    │
# │              ┆ Concern,           ┆                    ┆       ┆             ┆ Concern,          │
# │              ┆                    ┆                    ┆       ┆             ┆                   │
# │              ┆ Communi…           ┆                    ┆       ┆             ┆ <Lead>C…          │
# │ 000BAD50D026 ┆ Do you think       ┆ Distance learning  ┆ 3     ┆ null        ┆ <Lead>Do you      │
# │              ┆ students would     ┆                    ┆       ┆             ┆ think students    │
# │              ┆ bene…              ┆                    ┆       ┆             ┆ woul…             │
# │ 000E6DE9E817 ┆ Dear: Principal    ┆ Grades for         ┆ 3     ┆ null        ┆ Dear: Principal   │
# │              ┆                    ┆ extracurricular    ┆       ┆             ┆                   │
# │              ┆ I am arguing ag…   ┆ activ…             ┆       ┆             ┆ <Position>I am …  │
# │ 0016926B079C ┆ I think that       ┆ Distance learning  ┆ 3     ┆ null        ┆ <Position>I think │
# │              ┆ students would     ┆                    ┆       ┆             ┆ that students …   │
# │              ┆ bene…              ┆                    ┆       ┆             ┆                   │
# │ 00203C45FC55 ┆ It is every        ┆ Distance learning  ┆ 6     ┆ null        ┆ <Lead>It is every │
# │              ┆ student's dream to ┆                    ┆       ┆             ┆ student's drea…   │
# │              ┆ b…                 ┆                    ┆       ┆             ┆                   │
# │ …            ┆ …                  ┆ …                  ┆ …     ┆ …           ┆ …                 │
# │ FFE4B98E0B1E ┆ Although teacher   ┆ Summer projects    ┆ 4     ┆ null        ┆ <Counterclaim>Alt │
# │              ┆ designed summer…   ┆                    ┆       ┆             ┆ hough teacher d…  │
# │ FFE91DA2A101 ┆ Students should    ┆ Distance learning  ┆ 4     ┆ null        ┆ <Position>Student │
# │              ┆ take regular att…  ┆                    ┆       ┆             ┆ s should take r…  │
# │ FFF1442D6698 ┆ Every student      ┆ Summer projects    ┆ 6     ┆ null        ┆ <Lead>Every       │
# │              ┆ looks forward to   ┆                    ┆       ┆             ┆ student looks     │
# │              ┆ s…                 ┆                    ┆       ┆             ┆ forwar…           │
# │ FFF868E06176 ┆ Every summer       ┆ Summer projects    ┆ 3     ┆ null        ┆ <Lead>Every       │
# │              ┆ break, students    ┆                    ┆       ┆             ┆ summer break,     │
# │              ┆ are…               ┆                    ┆       ┆             ┆ studen…           │
# │ FFF964B8ACC0 ┆ Dear Principal,    ┆ Cell phones at     ┆ 3     ┆ null        ┆ Dear Principal,   │
# │              ┆                    ┆ school             ┆       ┆             ┆                   │
# │              ┆ I understand th…   ┆                    ┆       ┆             ┆ <Lead>I underst…  │
# └──────────────┴────────────────────┴────────────────────┴───────┴─────────────┴───────────────────┘

# %%
nol_sen.write_csv('nol_combined_tokened.csv')

# %% [markdown]
# # post-processing predicted discourse type

# %%
dt_pred = pl.read_csv('/kaggle/input/lal-aes2-infer-discourse-ds2/dt_pred.csv')
pred = softmax(dt_pred.select([f'pred_class_{c}' for c in range(7)]).to_numpy(), axis=-1).argmax(-1)
dt_pred = pl.concat([dt_pred, pl.DataFrame({'preds': pred})], how='horizontal')
dt_pred
# Out:
# shape: (80_275, 14)
# ┌────────────┬─────────────┬────────────┬───────┬───┬────────────┬────────────┬────────────┬───────┐
# │ essay_id   ┆ full_text   ┆ prompt_nam ┆ score ┆ … ┆ pred_class ┆ pred_class ┆ pred_class ┆ preds │
# │ ---        ┆ ---         ┆ e          ┆ ---   ┆   ┆ _4         ┆ _5         ┆ _6         ┆ ---   │
# │ str        ┆ str         ┆ ---        ┆ i64   ┆   ┆ ---        ┆ ---        ┆ ---        ┆ i64   │
# │            ┆             ┆ str        ┆       ┆   ┆ f64        ┆ f64        ┆ f64        ┆       │
# ╞════════════╪═════════════╪════════════╪═══════╪═══╪════════════╪════════════╪════════════╪═══════╡
# │ 000fe60_0  ┆ I am a      ┆ The Face   ┆ 3     ┆ … ┆ -1.611443  ┆ -2.436806  ┆ -2.911818  ┆ 0     │
# │            ┆ scientist   ┆ on Mars    ┆       ┆   ┆            ┆            ┆            ┆       │
# │            ┆ at NASA     ┆            ┆       ┆   ┆            ┆            ┆            ┆       │
# │            ┆ that is…    ┆            ┆       ┆   ┆            ┆            ┆            ┆       │
# │ 000fe60_1  ┆ I am a      ┆ The Face   ┆ 3     ┆ … ┆ -1.653093  ┆ -2.031184  ┆ -2.989719  ┆ 1     │
# │            ┆ scientist   ┆ on Mars    ┆       ┆   ┆            ┆            ┆            ┆       │
# │            ┆ at NASA     ┆            ┆       ┆   ┆            ┆            ┆            ┆       │
# │            ┆ that is…    ┆            ┆       ┆   ┆            ┆            ┆            ┆       │
# │ 000fe60_2  ┆ I am a      ┆ The Face   ┆ 3     ┆ … ┆ -1.293672  ┆ -2.232578  ┆ -2.454375  ┆ 1     │
# │            ┆ scientist   ┆ on Mars    ┆       ┆   ┆            ┆            ┆            ┆       │
# │            ┆ at NASA     ┆            ┆       ┆   ┆            ┆            ┆            ┆       │
# │            ┆ that is…    ┆            ┆       ┆   ┆            ┆            ┆            ┆       │
# │ 000fe60_3  ┆ I am a      ┆ The Face   ┆ 3     ┆ … ┆ -2.514192  ┆ 0.083378   ┆ -2.089296  ┆ 2     │
# │            ┆ scientist   ┆ on Mars    ┆       ┆   ┆            ┆            ┆            ┆       │
# │            ┆ at NASA     ┆            ┆       ┆   ┆            ┆            ┆            ┆       │
# │            ┆ that is…    ┆            ┆       ┆   ┆            ┆            ┆            ┆       │
# │ 000fe60_4  ┆ I am a      ┆ The Face   ┆ 3     ┆ … ┆ -1.797388  ┆ -1.81876   ┆ -2.286569  ┆ 2     │
# │            ┆ scientist   ┆ on Mars    ┆       ┆   ┆            ┆            ┆            ┆       │
# │            ┆ at NASA     ┆            ┆       ┆   ┆            ┆            ┆            ┆       │
# │            ┆ that is…    ┆            ┆       ┆   ┆            ┆            ┆            ┆       │
# │ …          ┆ …           ┆ …          ┆ …     ┆ … ┆ …          ┆ …          ┆ …          ┆ …     │
# │ fffed3e_7  ┆ Venus is    ┆ Exploring  ┆ 2     ┆ … ┆ -1.769132  ┆ -2.329039  ┆ -0.179665  ┆ 2     │
# │            ┆ worthy      ┆ Venus      ┆       ┆   ┆            ┆            ┆            ┆       │
# │            ┆ place to    ┆            ┆       ┆   ┆            ┆            ┆            ┆       │
# │            ┆ study b…    ┆            ┆       ┆   ┆            ┆            ┆            ┆       │
# │ fffed3e_8  ┆ Venus is    ┆ Exploring  ┆ 2     ┆ … ┆ -1.974055  ┆ -1.822579  ┆ -0.801626  ┆ 2     │
# │            ┆ worthy      ┆ Venus      ┆       ┆   ┆            ┆            ┆            ┆       │
# │            ┆ place to    ┆            ┆       ┆   ┆            ┆            ┆            ┆       │
# │            ┆ study b…    ┆            ┆       ┆   ┆            ┆            ┆            ┆       │
# │ fffed3e_9  ┆ Venus is    ┆ Exploring  ┆ 2     ┆ … ┆ -1.675161  ┆ 0.400315   ┆ 3.4489958  ┆ 6     │
# │            ┆ worthy      ┆ Venus      ┆       ┆   ┆            ┆            ┆            ┆       │
# │            ┆ place to    ┆            ┆       ┆   ┆            ┆            ┆            ┆       │
# │            ┆ study b…    ┆            ┆       ┆   ┆            ┆            ┆            ┆       │
# │ fffed3e_10 ┆ Venus is    ┆ Exploring  ┆ 2     ┆ … ┆ -0.863774  ┆ -0.936936  ┆ 1.0462234  ┆ 2     │
# │            ┆ worthy      ┆ Venus      ┆       ┆   ┆            ┆            ┆            ┆       │
# │            ┆ place to    ┆            ┆       ┆   ┆            ┆            ┆            ┆       │
# │            ┆ study b…    ┆            ┆       ┆   ┆            ┆            ┆            ┆       │
# │ fffed3e_11 ┆ Venus is    ┆ Exploring  ┆ 2     ┆ … ┆ 4.5634823  ┆ -1.085738  ┆ -0.334294  ┆ 4     │
# │            ┆ worthy      ┆ Venus      ┆       ┆   ┆            ┆            ┆            ┆       │
# │            ┆ place to    ┆            ┆       ┆   ┆            ┆            ┆            ┆       │
# │            ┆ study b…    ┆            ┆       ┆   ┆            ┆            ┆            ┆       │
# └────────────┴─────────────┴────────────┴───────┴───┴────────────┴────────────┴────────────┴───────┘

# %% [markdown]
# ## Merge consecutive dicsourse type (only position and claim)

# %%
new_repeated = []
for name, data in dt_pred.group_by(['full_text'], maintain_order=True):
    dtype = data['preds'].to_list()
    hold = -1
    for i in range(1, data.shape[0]):
        if dtype[i] not in [1, 2]:
            hold = dtype[i]
            continue
        if dtype[i] == dtype[i - 1] or dtype[i] == hold:
            hold = dtype[i]
            dtype[i] = -1
    
    new_repeated.append(dtype)

# %%
dt_map
# Out:
# {'Lead': 0,
#  'Position': 1,
#  'Claim': 2,
#  'Evidence': 3,
#  'Concluding Statement': 4,
#  'Counterclaim': 5,
#  'Rebuttal': 6,
#  'Repeated': -1}

# %%
dt_pred = dt_pred.with_columns(pl.Series(np.concatenate(new_repeated, axis=0)).alias('m_preds'))
dt_pred = dt_pred.with_columns(pl.col('m_preds').replace(rev_dt_map))
dt_pred = dt_pred.with_columns(pl.col('m_preds').replace(token_dt_map).alias('s_token'))
dt_pred = dt_pred.with_columns(pl.col('essay_id').str.replace_all('(_.*)', ''))
dt_pred = dt_pred.with_columns(pl.col('discourse_text').str.strip_chars(' ')).filter(pl.col('discourse_text') != '')
dt_pred
# Out:
# shape: (80_275, 16)
# ┌──────────┬─────────────┬─────────────┬───────┬───┬─────────────┬───────┬────────────┬────────────┐
# │ essay_id ┆ full_text   ┆ prompt_name ┆ score ┆ … ┆ pred_class_ ┆ preds ┆ m_preds    ┆ s_token    │
# │ ---      ┆ ---         ┆ ---         ┆ ---   ┆   ┆ 6           ┆ ---   ┆ ---        ┆ ---        │
# │ str      ┆ str         ┆ str         ┆ i64   ┆   ┆ ---         ┆ i64   ┆ str        ┆ str        │
# │          ┆             ┆             ┆       ┆   ┆ f64         ┆       ┆            ┆            │
# ╞══════════╪═════════════╪═════════════╪═══════╪═══╪═════════════╪═══════╪════════════╪════════════╡
# │ 000fe60  ┆ I am a      ┆ The Face on ┆ 3     ┆ … ┆ -2.911818   ┆ 0     ┆ Lead       ┆ <Lead>     │
# │          ┆ scientist   ┆ Mars        ┆       ┆   ┆             ┆       ┆            ┆            │
# │          ┆ at NASA     ┆             ┆       ┆   ┆             ┆       ┆            ┆            │
# │          ┆ that is…    ┆             ┆       ┆   ┆             ┆       ┆            ┆            │
# │ 000fe60  ┆ I am a      ┆ The Face on ┆ 3     ┆ … ┆ -2.989719   ┆ 1     ┆ Position   ┆ <Position> │
# │          ┆ scientist   ┆ Mars        ┆       ┆   ┆             ┆       ┆            ┆            │
# │          ┆ at NASA     ┆             ┆       ┆   ┆             ┆       ┆            ┆            │
# │          ┆ that is…    ┆             ┆       ┆   ┆             ┆       ┆            ┆            │
# │ 000fe60  ┆ I am a      ┆ The Face on ┆ 3     ┆ … ┆ -2.454375   ┆ 1     ┆ Repeated   ┆            │
# │          ┆ scientist   ┆ Mars        ┆       ┆   ┆             ┆       ┆            ┆            │
# │          ┆ at NASA     ┆             ┆       ┆   ┆             ┆       ┆            ┆            │
# │          ┆ that is…    ┆             ┆       ┆   ┆             ┆       ┆            ┆            │
# │ 000fe60  ┆ I am a      ┆ The Face on ┆ 3     ┆ … ┆ -2.089296   ┆ 2     ┆ Claim      ┆ <Claim>    │
# │          ┆ scientist   ┆ Mars        ┆       ┆   ┆             ┆       ┆            ┆            │
# │          ┆ at NASA     ┆             ┆       ┆   ┆             ┆       ┆            ┆            │
# │          ┆ that is…    ┆             ┆       ┆   ┆             ┆       ┆            ┆            │
# │ 000fe60  ┆ I am a      ┆ The Face on ┆ 3     ┆ … ┆ -2.286569   ┆ 2     ┆ Repeated   ┆            │
# │          ┆ scientist   ┆ Mars        ┆       ┆   ┆             ┆       ┆            ┆            │
# │          ┆ at NASA     ┆             ┆       ┆   ┆             ┆       ┆            ┆            │
# │          ┆ that is…    ┆             ┆       ┆   ┆             ┆       ┆            ┆            │
# │ …        ┆ …           ┆ …           ┆ …     ┆ … ┆ …           ┆ …     ┆ …          ┆ …          │
# │ fffed3e  ┆ Venus is    ┆ Exploring   ┆ 2     ┆ … ┆ -0.179665   ┆ 2     ┆ Claim      ┆ <Claim>    │
# │          ┆ worthy      ┆ Venus       ┆       ┆   ┆             ┆       ┆            ┆            │
# │          ┆ place to    ┆             ┆       ┆   ┆             ┆       ┆            ┆            │
# │          ┆ study b…    ┆             ┆       ┆   ┆             ┆       ┆            ┆            │
# │ fffed3e  ┆ Venus is    ┆ Exploring   ┆ 2     ┆ … ┆ -0.801626   ┆ 2     ┆ Repeated   ┆            │
# │          ┆ worthy      ┆ Venus       ┆       ┆   ┆             ┆       ┆            ┆            │
# │          ┆ place to    ┆             ┆       ┆   ┆             ┆       ┆            ┆            │
# │          ┆ study b…    ┆             ┆       ┆   ┆             ┆       ┆            ┆            │
# │ fffed3e  ┆ Venus is    ┆ Exploring   ┆ 2     ┆ … ┆ 3.4489958   ┆ 6     ┆ Rebuttal   ┆ <Rebuttal> │
# │          ┆ worthy      ┆ Venus       ┆       ┆   ┆             ┆       ┆            ┆            │
# │          ┆ place to    ┆             ┆       ┆   ┆             ┆       ┆            ┆            │
# │          ┆ study b…    ┆             ┆       ┆   ┆             ┆       ┆            ┆            │
# │ fffed3e  ┆ Venus is    ┆ Exploring   ┆ 2     ┆ … ┆ 1.0462234   ┆ 2     ┆ Claim      ┆ <Claim>    │
# │          ┆ worthy      ┆ Venus       ┆       ┆   ┆             ┆       ┆            ┆            │
# │          ┆ place to    ┆             ┆       ┆   ┆             ┆       ┆            ┆            │
# │          ┆ study b…    ┆             ┆       ┆   ┆             ┆       ┆            ┆            │
# │ fffed3e  ┆ Venus is    ┆ Exploring   ┆ 2     ┆ … ┆ -0.334294   ┆ 4     ┆ Concluding ┆ <Concludin │
# │          ┆ worthy      ┆ Venus       ┆       ┆   ┆             ┆       ┆ Statement  ┆ g>         │
# │          ┆ place to    ┆             ┆       ┆   ┆             ┆       ┆            ┆            │
# │          ┆ study b…    ┆             ┆       ┆   ┆             ┆       ┆            ┆            │
# └──────────┴─────────────┴─────────────┴───────┴───┴─────────────┴───────┴────────────┴────────────┘

# %% [markdown]
# ## Make sure there is only one Lead and Conclude

# %%
new_s_token = []

for name, data in dt_pred.group_by(['essay_id', 'full_text'], maintain_order=True):

    rev_s_token = ','.join(data['s_token'].reverse().to_list())
    t_len = data.group_by("s_token").len()
    
    for k in t_len.to_dicts():
        if k['s_token'] == '<Lead>':
            if k['len'] > 1:
                lead_occur = rev_s_token.count('<Lead>')
                rev_s_token = rev_s_token.replace('<Lead>', '', lead_occur - 1)

    new_s_token.extend(reversed(rev_s_token.split(',')))

# %%
dt_pred = dt_pred.with_columns(new_s_token=pl.Series(new_s_token))
dt_pred
# Out:
# shape: (80_275, 17)
# ┌──────────┬─────────────┬─────────────┬───────┬───┬───────┬─────────────┬────────────┬────────────┐
# │ essay_id ┆ full_text   ┆ prompt_name ┆ score ┆ … ┆ preds ┆ m_preds     ┆ s_token    ┆ new_s_toke │
# │ ---      ┆ ---         ┆ ---         ┆ ---   ┆   ┆ ---   ┆ ---         ┆ ---        ┆ n          │
# │ str      ┆ str         ┆ str         ┆ i64   ┆   ┆ i64   ┆ str         ┆ str        ┆ ---        │
# │          ┆             ┆             ┆       ┆   ┆       ┆             ┆            ┆ str        │
# ╞══════════╪═════════════╪═════════════╪═══════╪═══╪═══════╪═════════════╪════════════╪════════════╡
# │ 000fe60  ┆ I am a      ┆ The Face on ┆ 3     ┆ … ┆ 0     ┆ Lead        ┆ <Lead>     ┆ <Lead>     │
# │          ┆ scientist   ┆ Mars        ┆       ┆   ┆       ┆             ┆            ┆            │
# │          ┆ at NASA     ┆             ┆       ┆   ┆       ┆             ┆            ┆            │
# │          ┆ that is…    ┆             ┆       ┆   ┆       ┆             ┆            ┆            │
# │ 000fe60  ┆ I am a      ┆ The Face on ┆ 3     ┆ … ┆ 1     ┆ Position    ┆ <Position> ┆ <Position> │
# │          ┆ scientist   ┆ Mars        ┆       ┆   ┆       ┆             ┆            ┆            │
# │          ┆ at NASA     ┆             ┆       ┆   ┆       ┆             ┆            ┆            │
# │          ┆ that is…    ┆             ┆       ┆   ┆       ┆             ┆            ┆            │
# │ 000fe60  ┆ I am a      ┆ The Face on ┆ 3     ┆ … ┆ 1     ┆ Repeated    ┆            ┆            │
# │          ┆ scientist   ┆ Mars        ┆       ┆   ┆       ┆             ┆            ┆            │
# │          ┆ at NASA     ┆             ┆       ┆   ┆       ┆             ┆            ┆            │
# │          ┆ that is…    ┆             ┆       ┆   ┆       ┆             ┆            ┆            │
# │ 000fe60  ┆ I am a      ┆ The Face on ┆ 3     ┆ … ┆ 2     ┆ Claim       ┆ <Claim>    ┆ <Claim>    │
# │          ┆ scientist   ┆ Mars        ┆       ┆   ┆       ┆             ┆            ┆            │
# │          ┆ at NASA     ┆             ┆       ┆   ┆       ┆             ┆            ┆            │
# │          ┆ that is…    ┆             ┆       ┆   ┆       ┆             ┆            ┆            │
# │ 000fe60  ┆ I am a      ┆ The Face on ┆ 3     ┆ … ┆ 2     ┆ Repeated    ┆            ┆            │
# │          ┆ scientist   ┆ Mars        ┆       ┆   ┆       ┆             ┆            ┆            │
# │          ┆ at NASA     ┆             ┆       ┆   ┆       ┆             ┆            ┆            │
# │          ┆ that is…    ┆             ┆       ┆   ┆       ┆             ┆            ┆            │
# │ …        ┆ …           ┆ …           ┆ …     ┆ … ┆ …     ┆ …           ┆ …          ┆ …          │
# │ fffed3e  ┆ Venus is    ┆ Exploring   ┆ 2     ┆ … ┆ 2     ┆ Claim       ┆ <Claim>    ┆ <Claim>    │
# │          ┆ worthy      ┆ Venus       ┆       ┆   ┆       ┆             ┆            ┆            │
# │          ┆ place to    ┆             ┆       ┆   ┆       ┆             ┆            ┆            │
# │          ┆ study b…    ┆             ┆       ┆   ┆       ┆             ┆            ┆            │
# │ fffed3e  ┆ Venus is    ┆ Exploring   ┆ 2     ┆ … ┆ 2     ┆ Repeated    ┆            ┆            │
# │          ┆ worthy      ┆ Venus       ┆       ┆   ┆       ┆             ┆            ┆            │
# │          ┆ place to    ┆             ┆       ┆   ┆       ┆             ┆            ┆            │
# │          ┆ study b…    ┆             ┆       ┆   ┆       ┆             ┆            ┆            │
# │ fffed3e  ┆ Venus is    ┆ Exploring   ┆ 2     ┆ … ┆ 6     ┆ Rebuttal    ┆ <Rebuttal> ┆ <Rebuttal> │
# │          ┆ worthy      ┆ Venus       ┆       ┆   ┆       ┆             ┆            ┆            │
# │          ┆ place to    ┆             ┆       ┆   ┆       ┆             ┆            ┆            │
# │          ┆ study b…    ┆             ┆       ┆   ┆       ┆             ┆            ┆            │
# │ fffed3e  ┆ Venus is    ┆ Exploring   ┆ 2     ┆ … ┆ 2     ┆ Claim       ┆ <Claim>    ┆ <Claim>    │
# │          ┆ worthy      ┆ Venus       ┆       ┆   ┆       ┆             ┆            ┆            │
# │          ┆ place to    ┆             ┆       ┆   ┆       ┆             ┆            ┆            │
# │          ┆ study b…    ┆             ┆       ┆   ┆       ┆             ┆            ┆            │
# │ fffed3e  ┆ Venus is    ┆ Exploring   ┆ 2     ┆ … ┆ 4     ┆ Concluding  ┆ <Concludin ┆ <Concludin │
# │          ┆ worthy      ┆ Venus       ┆       ┆   ┆       ┆ Statement   ┆ g>         ┆ g>         │
# │          ┆ place to    ┆             ┆       ┆   ┆       ┆             ┆            ┆            │
# │          ┆ study b…    ┆             ┆       ┆   ┆       ┆             ┆            ┆            │
# └──────────┴─────────────┴─────────────┴───────┴───┴───────┴─────────────┴────────────┴────────────┘

# %%
new_s_token = []

for name, data in dt_pred.group_by(['essay_id', 'full_text'], maintain_order=True):

    rev_s_token = ','.join(data['new_s_token'].to_list())
    t_len = data.group_by("new_s_token").len()
    
    for k in t_len.to_dicts():
        if k['new_s_token'] == '<Concluding>':
            if k['len'] > 1:
                conclude_occur = rev_s_token.count('<Concluding>')
                rev_s_token = rev_s_token.replace('<Concluding>', '', conclude_occur - 1)

    new_s_token.extend(rev_s_token.split(','))

# %%
dt_pred = dt_pred.with_columns(new_s_token=pl.Series(new_s_token))
dt_pred
# Out:
# shape: (80_275, 17)
# ┌──────────┬─────────────┬─────────────┬───────┬───┬───────┬─────────────┬────────────┬────────────┐
# │ essay_id ┆ full_text   ┆ prompt_name ┆ score ┆ … ┆ preds ┆ m_preds     ┆ s_token    ┆ new_s_toke │
# │ ---      ┆ ---         ┆ ---         ┆ ---   ┆   ┆ ---   ┆ ---         ┆ ---        ┆ n          │
# │ str      ┆ str         ┆ str         ┆ i64   ┆   ┆ i64   ┆ str         ┆ str        ┆ ---        │
# │          ┆             ┆             ┆       ┆   ┆       ┆             ┆            ┆ str        │
# ╞══════════╪═════════════╪═════════════╪═══════╪═══╪═══════╪═════════════╪════════════╪════════════╡
# │ 000fe60  ┆ I am a      ┆ The Face on ┆ 3     ┆ … ┆ 0     ┆ Lead        ┆ <Lead>     ┆ <Lead>     │
# │          ┆ scientist   ┆ Mars        ┆       ┆   ┆       ┆             ┆            ┆            │
# │          ┆ at NASA     ┆             ┆       ┆   ┆       ┆             ┆            ┆            │
# │          ┆ that is…    ┆             ┆       ┆   ┆       ┆             ┆            ┆            │
# │ 000fe60  ┆ I am a      ┆ The Face on ┆ 3     ┆ … ┆ 1     ┆ Position    ┆ <Position> ┆ <Position> │
# │          ┆ scientist   ┆ Mars        ┆       ┆   ┆       ┆             ┆            ┆            │
# │          ┆ at NASA     ┆             ┆       ┆   ┆       ┆             ┆            ┆            │
# │          ┆ that is…    ┆             ┆       ┆   ┆       ┆             ┆            ┆            │
# │ 000fe60  ┆ I am a      ┆ The Face on ┆ 3     ┆ … ┆ 1     ┆ Repeated    ┆            ┆            │
# │          ┆ scientist   ┆ Mars        ┆       ┆   ┆       ┆             ┆            ┆            │
# │          ┆ at NASA     ┆             ┆       ┆   ┆       ┆             ┆            ┆            │
# │          ┆ that is…    ┆             ┆       ┆   ┆       ┆             ┆            ┆            │
# │ 000fe60  ┆ I am a      ┆ The Face on ┆ 3     ┆ … ┆ 2     ┆ Claim       ┆ <Claim>    ┆ <Claim>    │
# │          ┆ scientist   ┆ Mars        ┆       ┆   ┆       ┆             ┆            ┆            │
# │          ┆ at NASA     ┆             ┆       ┆   ┆       ┆             ┆            ┆            │
# │          ┆ that is…    ┆             ┆       ┆   ┆       ┆             ┆            ┆            │
# │ 000fe60  ┆ I am a      ┆ The Face on ┆ 3     ┆ … ┆ 2     ┆ Repeated    ┆            ┆            │
# │          ┆ scientist   ┆ Mars        ┆       ┆   ┆       ┆             ┆            ┆            │
# │          ┆ at NASA     ┆             ┆       ┆   ┆       ┆             ┆            ┆            │
# │          ┆ that is…    ┆             ┆       ┆   ┆       ┆             ┆            ┆            │
# │ …        ┆ …           ┆ …           ┆ …     ┆ … ┆ …     ┆ …           ┆ …          ┆ …          │
# │ fffed3e  ┆ Venus is    ┆ Exploring   ┆ 2     ┆ … ┆ 2     ┆ Claim       ┆ <Claim>    ┆ <Claim>    │
# │          ┆ worthy      ┆ Venus       ┆       ┆   ┆       ┆             ┆            ┆            │
# │          ┆ place to    ┆             ┆       ┆   ┆       ┆             ┆            ┆            │
# │          ┆ study b…    ┆             ┆       ┆   ┆       ┆             ┆            ┆            │
# │ fffed3e  ┆ Venus is    ┆ Exploring   ┆ 2     ┆ … ┆ 2     ┆ Repeated    ┆            ┆            │
# │          ┆ worthy      ┆ Venus       ┆       ┆   ┆       ┆             ┆            ┆            │
# │          ┆ place to    ┆             ┆       ┆   ┆       ┆             ┆            ┆            │
# │          ┆ study b…    ┆             ┆       ┆   ┆       ┆             ┆            ┆            │
# │ fffed3e  ┆ Venus is    ┆ Exploring   ┆ 2     ┆ … ┆ 6     ┆ Rebuttal    ┆ <Rebuttal> ┆ <Rebuttal> │
# │          ┆ worthy      ┆ Venus       ┆       ┆   ┆       ┆             ┆            ┆            │
# │          ┆ place to    ┆             ┆       ┆   ┆       ┆             ┆            ┆            │
# │          ┆ study b…    ┆             ┆       ┆   ┆       ┆             ┆            ┆            │
# │ fffed3e  ┆ Venus is    ┆ Exploring   ┆ 2     ┆ … ┆ 2     ┆ Claim       ┆ <Claim>    ┆ <Claim>    │
# │          ┆ worthy      ┆ Venus       ┆       ┆   ┆       ┆             ┆            ┆            │
# │          ┆ place to    ┆             ┆       ┆   ┆       ┆             ┆            ┆            │
# │          ┆ study b…    ┆             ┆       ┆   ┆       ┆             ┆            ┆            │
# │ fffed3e  ┆ Venus is    ┆ Exploring   ┆ 2     ┆ … ┆ 4     ┆ Concluding  ┆ <Concludin ┆ <Concludin │
# │          ┆ worthy      ┆ Venus       ┆       ┆   ┆       ┆ Statement   ┆ g>         ┆ g>         │
# │          ┆ place to    ┆             ┆       ┆   ┆       ┆             ┆            ┆            │
# │          ┆ study b…    ┆             ┆       ┆   ┆       ┆             ┆            ┆            │
# └──────────┴─────────────┴─────────────┴───────┴───┴───────┴─────────────┴────────────┴────────────┘

# %%
ko_sen = dt_pred.with_columns(pl.concat_str([pl.col('new_s_token'), pl.col('discourse_text')], separator="").alias('tokened_text'))
ko_sen = ko_sen.group_by(selected_cols, maintain_order=True).agg([
    pl.col('tokened_text').str.concat(' ')
])
ko_sen
# Out:
# shape: (4_434, 6)
# ┌──────────┬─────────────────────┬─────────────────────┬───────┬─────────────┬─────────────────────┐
# │ essay_id ┆ full_text           ┆ prompt_name         ┆ score ┆ kaggle_only ┆ tokened_text        │
# │ ---      ┆ ---                 ┆ ---                 ┆ ---   ┆ ---         ┆ ---                 │
# │ str      ┆ str                 ┆ str                 ┆ i64   ┆ bool        ┆ str                 │
# ╞══════════╪═════════════════════╪═════════════════════╪═══════╪═════════════╪═════════════════════╡
# │ 000fe60  ┆ I am a scientist at ┆ The Face on Mars    ┆ 3     ┆ true        ┆ <Lead>I am a        │
# │          ┆ NASA that is…       ┆                     ┆       ┆             ┆ scientist at NASA   │
# │          ┆                     ┆                     ┆       ┆             ┆ t…                  │
# │ 001ab80  ┆ People always wish  ┆ Driverless cars     ┆ 4     ┆ true        ┆ <Claim>People       │
# │          ┆ they had the …      ┆                     ┆       ┆             ┆ always wish they h… │
# │ 001bdc0  ┆ We all heard about  ┆ Exploring Venus     ┆ 4     ┆ true        ┆ <Lead>We all heard  │
# │          ┆ Venus, the pl…      ┆                     ┆       ┆             ┆ about Venus, …      │
# │ 0033037  ┆ The posibilty of a  ┆ Facial action       ┆ 2     ┆ true        ┆ <Position>The       │
# │          ┆ face reconizi…      ┆ coding system       ┆       ┆             ┆ posibilty of a fac… │
# │ 0065bd6  ┆ Driverless cars     ┆ Driverless cars     ┆ 3     ┆ true        ┆ <Claim>Driverless   │
# │          ┆ should not exsis…   ┆                     ┆       ┆             ┆ cars should no…     │
# │ …        ┆ …                   ┆ …                   ┆ …     ┆ …           ┆ …                   │
# │ ffbd0b4  ┆ Do you think you    ┆ Exploring Venus     ┆ 2     ┆ true        ┆ <Lead>Do you think  │
# │          ┆ could suvive in…    ┆                     ┆       ┆             ┆ you could suv…      │
# │ ffcb061  ┆ Becoming a Seagoing ┆ "A Cowboy Who Rode  ┆ 3     ┆ true        ┆ <Position>Becoming  │
# │          ┆ Cowboy is a …       ┆ the Waves"          ┆       ┆             ┆ a Seagoing Co…      │
# │ ffcb264  ┆ Using technology is ┆ Facial action       ┆ 2     ┆ true        ┆ <Claim>Using        │
# │          ┆ a good way t…       ┆ coding system       ┆       ┆             ┆ technology is a     │
# │          ┆                     ┆                     ┆       ┆             ┆ goo…                │
# │ ffd378d  ┆ the story " The     ┆ Exploring Venus     ┆ 2     ┆ true        ┆ <Lead>the story "   │
# │          ┆ Challenge of Exp…   ┆                     ┆       ┆             ┆ The Challenge …     │
# │ fffed3e  ┆ Venus is worthy     ┆ Exploring Venus     ┆ 2     ┆ true        ┆ <Position>Venus is  │
# │          ┆ place to study b…   ┆                     ┆       ┆             ┆ worthy place …      │
# └──────────┴─────────────────────┴─────────────────────┴───────┴─────────────┴─────────────────────┘

# %%
combined_token = pl.concat([ko_sen, nko_sen]).sort('essay_id')
combined_token = combined_token.with_columns(pl.col('tokened_text').str.replace_all(pat_1, pat_2))
combined_token # un-filtered
# Out:
# shape: (17_305, 6)
# ┌──────────┬─────────────────────┬─────────────────────┬───────┬─────────────┬─────────────────────┐
# │ essay_id ┆ full_text           ┆ prompt_name         ┆ score ┆ kaggle_only ┆ tokened_text        │
# │ ---      ┆ ---                 ┆ ---                 ┆ ---   ┆ ---         ┆ ---                 │
# │ str      ┆ str                 ┆ str                 ┆ i64   ┆ bool        ┆ str                 │
# ╞══════════╪═════════════════════╪═════════════════════╪═══════╪═════════════╪═════════════════════╡
# │ 000d118  ┆ Many people have    ┆ Car-free cities     ┆ 3     ┆ false       ┆ <Lead>Many people   │
# │          ┆ car where they …    ┆                     ┆       ┆             ┆ have car where…     │
# │ 000fe60  ┆ I am a scientist at ┆ The Face on Mars    ┆ 3     ┆ true        ┆ <Lead>I am a        │
# │          ┆ NASA that is…       ┆                     ┆       ┆             ┆ scientist at NASA   │
# │          ┆                     ┆                     ┆       ┆             ┆ t…                  │
# │ 001ab80  ┆ People always wish  ┆ Driverless cars     ┆ 4     ┆ true        ┆ <Claim>People       │
# │          ┆ they had the …      ┆                     ┆       ┆             ┆ always wish they h… │
# │ 001bdc0  ┆ We all heard about  ┆ Exploring Venus     ┆ 4     ┆ true        ┆ <Lead>We all heard  │
# │          ┆ Venus, the pl…      ┆                     ┆       ┆             ┆ about Venus, …      │
# │ 002ba53  ┆ Dear, State Senator ┆ Does the electoral  ┆ 3     ┆ false       ┆ Dear, State Senator │
# │          ┆                     ┆ college work?       ┆       ┆             ┆                     │
# │          ┆ This is a l…        ┆                     ┆       ┆             ┆ <Position>T…        │
# │ …        ┆ …                   ┆ …                   ┆ …     ┆ …           ┆ …                   │
# │ ffd378d  ┆ the story " The     ┆ Exploring Venus     ┆ 2     ┆ true        ┆ <Lead>the story "   │
# │          ┆ Challenge of Exp…   ┆                     ┆       ┆             ┆ The Challenge …     │
# │ ffddf1f  ┆ Technology has      ┆ Facial action       ┆ 4     ┆ false       ┆ <Lead>Technology    │
# │          ┆ changed a lot of …  ┆ coding system       ┆       ┆             ┆ has changed a l…    │
# │ fff016d  ┆ If you don't like   ┆ "A Cowboy Who Rode  ┆ 2     ┆ false       ┆ <Lead>If you don't  │
# │          ┆ sitting around…     ┆ the Waves"          ┆       ┆             ┆ like sitting …      │
# │ fffb49b  ┆ In "The Challenge   ┆ Exploring Venus     ┆ 1     ┆ false       ┆ <Position>In "The   │
# │          ┆ of Exporing Ve…     ┆                     ┆       ┆             ┆ Challenge of E…     │
# │ fffed3e  ┆ Venus is worthy     ┆ Exploring Venus     ┆ 2     ┆ true        ┆ <Position>Venus is  │
# │          ┆ place to study b…   ┆                     ┆       ┆             ┆ worthy place …      │
# └──────────┴─────────────────────┴─────────────────────┴───────┴─────────────┴─────────────────────┘

# %%
tt = combined_token.with_columns([pl.col('tokened_text').str.count_matches(count_dt[i]).alias(f'{rev_dt_map[i]}' +'_count') for i in range(7)]).group_by(['score']).mean().sort('score')
tt.to_pandas().style.background_gradient()
# Out:
# <style type="text/css">
# #T_66ee8_row0_col0, #T_66ee8_row0_col6, #T_66ee8_row0_col7, #T_66ee8_row0_col8, #T_66ee8_row0_col9, #T_66ee8_row0_col10, #T_66ee8_row0_col11, #T_66ee8_row0_col12, #T_66ee8_row5_col4 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_66ee8_row0_col4 {
#   background-color: #328dbf;
#   color: #f1f1f1;
# }
# #T_66ee8_row1_col0 {
#   background-color: #dbdaeb;
#   color: #000000;
# }
# #T_66ee8_row1_col4 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_66ee8_row1_col6 {
#   background-color: #e4e1ef;
#   color: #000000;
# }
# #T_66ee8_row1_col7 {
#   background-color: #2182b9;
#   color: #f1f1f1;
# }
# #T_66ee8_row1_col8 {
#   background-color: #bcc7e1;
#   color: #000000;
# }
# #T_66ee8_row1_col9 {
#   background-color: #e1dfed;
#   color: #000000;
# }
# #T_66ee8_row1_col10, #T_66ee8_row4_col11 {
#   background-color: #65a3cb;
#   color: #f1f1f1;
# }
# #T_66ee8_row1_col11 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# #T_66ee8_row1_col12 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_66ee8_row2_col0 {
#   background-color: #9cb9d9;
#   color: #000000;
# }
# #T_66ee8_row2_col4 {
#   background-color: #0f76b3;
#   color: #f1f1f1;
# }
# #T_66ee8_row2_col6 {
#   background-color: #9fbad9;
#   color: #000000;
# }
# #T_66ee8_row2_col7 {
#   background-color: #046097;
#   color: #f1f1f1;
# }
# #T_66ee8_row2_col8 {
#   background-color: #3790c0;
#   color: #f1f1f1;
# }
# #T_66ee8_row2_col9 {
#   background-color: #5ea0ca;
#   color: #f1f1f1;
# }
# #T_66ee8_row2_col10 {
#   background-color: #0771b1;
#   color: #f1f1f1;
# }
# #T_66ee8_row2_col11 {
#   background-color: #d4d4e8;
#   color: #000000;
# }
# #T_66ee8_row2_col12 {
#   background-color: #e2dfee;
#   color: #000000;
# }
# #T_66ee8_row3_col0, #T_66ee8_row3_col6 {
#   background-color: #4295c3;
#   color: #f1f1f1;
# }
# #T_66ee8_row3_col4, #T_66ee8_row3_col7, #T_66ee8_row5_col0, #T_66ee8_row5_col6, #T_66ee8_row5_col8, #T_66ee8_row5_col9, #T_66ee8_row5_col10, #T_66ee8_row5_col11, #T_66ee8_row5_col12 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_66ee8_row3_col8 {
#   background-color: #045382;
#   color: #f1f1f1;
# }
# #T_66ee8_row3_col9 {
#   background-color: #0566a0;
#   color: #f1f1f1;
# }
# #T_66ee8_row3_col10 {
#   background-color: #0569a5;
#   color: #f1f1f1;
# }
# #T_66ee8_row3_col11 {
#   background-color: #acc0dd;
#   color: #000000;
# }
# #T_66ee8_row3_col12 {
#   background-color: #c1cae2;
#   color: #000000;
# }
# #T_66ee8_row4_col0 {
#   background-color: #0567a2;
#   color: #f1f1f1;
# }
# #T_66ee8_row4_col4 {
#   background-color: #e3e0ee;
#   color: #000000;
# }
# #T_66ee8_row4_col6 {
#   background-color: #045687;
#   color: #f1f1f1;
# }
# #T_66ee8_row4_col7 {
#   background-color: #04649e;
#   color: #f1f1f1;
# }
# #T_66ee8_row4_col8 {
#   background-color: #023f64;
#   color: #f1f1f1;
# }
# #T_66ee8_row4_col9 {
#   background-color: #03466e;
#   color: #f1f1f1;
# }
# #T_66ee8_row4_col10 {
#   background-color: #034871;
#   color: #f1f1f1;
# }
# #T_66ee8_row4_col12 {
#   background-color: #79abd0;
#   color: #f1f1f1;
# }
# #T_66ee8_row5_col7 {
#   background-color: #056aa6;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_66ee8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_66ee8_level0_col0" class="col_heading level0 col0" >score</th>
#       <th id="T_66ee8_level0_col1" class="col_heading level0 col1" >essay_id</th>
#       <th id="T_66ee8_level0_col2" class="col_heading level0 col2" >full_text</th>
#       <th id="T_66ee8_level0_col3" class="col_heading level0 col3" >prompt_name</th>
#       <th id="T_66ee8_level0_col4" class="col_heading level0 col4" >kaggle_only</th>
#       <th id="T_66ee8_level0_col5" class="col_heading level0 col5" >tokened_text</th>
#       <th id="T_66ee8_level0_col6" class="col_heading level0 col6" >Lead_count</th>
#       <th id="T_66ee8_level0_col7" class="col_heading level0 col7" >Position_count</th>
#       <th id="T_66ee8_level0_col8" class="col_heading level0 col8" >Claim_count</th>
#       <th id="T_66ee8_level0_col9" class="col_heading level0 col9" >Evidence_count</th>
#       <th id="T_66ee8_level0_col10" class="col_heading level0 col10" >Concluding Statement_count</th>
#       <th id="T_66ee8_level0_col11" class="col_heading level0 col11" >Counterclaim_count</th>
#       <th id="T_66ee8_level0_col12" class="col_heading level0 col12" >Rebuttal_count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_66ee8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_66ee8_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_66ee8_row0_col1" class="data row0 col1" >None</td>
#       <td id="T_66ee8_row0_col2" class="data row0 col2" >None</td>
#       <td id="T_66ee8_row0_col3" class="data row0 col3" >None</td>
#       <td id="T_66ee8_row0_col4" class="data row0 col4" >0.245208</td>
#       <td id="T_66ee8_row0_col5" class="data row0 col5" >None</td>
#       <td id="T_66ee8_row0_col6" class="data row0 col6" >0.320288</td>
#       <td id="T_66ee8_row0_col7" class="data row0 col7" >0.623802</td>
#       <td id="T_66ee8_row0_col8" class="data row0 col8" >1.186901</td>
#       <td id="T_66ee8_row0_col9" class="data row0 col9" >1.888179</td>
#       <td id="T_66ee8_row0_col10" class="data row0 col10" >0.349840</td>
#       <td id="T_66ee8_row0_col11" class="data row0 col11" >0.096645</td>
#       <td id="T_66ee8_row0_col12" class="data row0 col12" >0.076677</td>
#     </tr>
#     <tr>
#       <th id="T_66ee8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_66ee8_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_66ee8_row1_col1" class="data row1 col1" >None</td>
#       <td id="T_66ee8_row1_col2" class="data row1 col2" >None</td>
#       <td id="T_66ee8_row1_col3" class="data row1 col3" >None</td>
#       <td id="T_66ee8_row1_col4" class="data row1 col4" >0.214059</td>
#       <td id="T_66ee8_row1_col5" class="data row1 col5" >None</td>
#       <td id="T_66ee8_row1_col6" class="data row1 col6" >0.403769</td>
#       <td id="T_66ee8_row1_col7" class="data row1 col7" >1.043405</td>
#       <td id="T_66ee8_row1_col8" class="data row1 col8" >2.206013</td>
#       <td id="T_66ee8_row1_col9" class="data row1 col9" >2.238408</td>
#       <td id="T_66ee8_row1_col10" class="data row1 col10" >0.683676</td>
#       <td id="T_66ee8_row1_col11" class="data row1 col11" >0.225916</td>
#       <td id="T_66ee8_row1_col12" class="data row1 col12" >0.142071</td>
#     </tr>
#     <tr>
#       <th id="T_66ee8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_66ee8_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_66ee8_row2_col1" class="data row2 col1" >None</td>
#       <td id="T_66ee8_row2_col2" class="data row2 col2" >None</td>
#       <td id="T_66ee8_row2_col3" class="data row2 col3" >None</td>
#       <td id="T_66ee8_row2_col4" class="data row2 col4" >0.266168</td>
#       <td id="T_66ee8_row2_col5" class="data row2 col5" >None</td>
#       <td id="T_66ee8_row2_col6" class="data row2 col6" >0.522619</td>
#       <td id="T_66ee8_row2_col7" class="data row2 col7" >1.141765</td>
#       <td id="T_66ee8_row2_col8" class="data row2 col8" >3.233992</td>
#       <td id="T_66ee8_row2_col9" class="data row2 col9" >2.992673</td>
#       <td id="T_66ee8_row2_col10" class="data row2 col10" >0.818732</td>
#       <td id="T_66ee8_row2_col11" class="data row2 col11" >0.337369</td>
#       <td id="T_66ee8_row2_col12" class="data row2 col12" >0.250080</td>
#     </tr>
#     <tr>
#       <th id="T_66ee8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_66ee8_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_66ee8_row3_col1" class="data row3 col1" >None</td>
#       <td id="T_66ee8_row3_col2" class="data row3 col2" >None</td>
#       <td id="T_66ee8_row3_col3" class="data row3 col3" >None</td>
#       <td id="T_66ee8_row3_col4" class="data row3 col4" >0.330871</td>
#       <td id="T_66ee8_row3_col5" class="data row3 col5" >None</td>
#       <td id="T_66ee8_row3_col6" class="data row3 col6" >0.628120</td>
#       <td id="T_66ee8_row3_col7" class="data row3 col7" >1.242741</td>
#       <td id="T_66ee8_row3_col8" class="data row3 col8" >4.153591</td>
#       <td id="T_66ee8_row3_col9" class="data row3 col9" >3.525981</td>
#       <td id="T_66ee8_row3_col10" class="data row3 c

# %%
tt = combined_token.filter(pl.col('kaggle_only') == True).with_columns([pl.col('tokened_text').str.count_matches(count_dt[i]).alias(f'{rev_dt_map[i]}' +'_count') for i in range(7)]).group_by(['score']).mean().sort('score')
tt.to_pandas().style.background_gradient()
# Out:
# <style type="text/css">
# #T_e4629_row0_col0, #T_e4629_row0_col4, #T_e4629_row0_col7, #T_e4629_row0_col8, #T_e4629_row0_col10, #T_e4629_row0_col11, #T_e4629_row1_col4, #T_e4629_row1_col6, #T_e4629_row1_col8, #T_e4629_row1_col9, #T_e4629_row1_col12, #T_e4629_row2_col4, #T_e4629_row3_col4, #T_e4629_row4_col4, #T_e4629_row5_col4 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_e4629_row0_col6 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_e4629_row0_col9 {
#   background-color: #e1dfed;
#   color: #000000;
# }
# #T_e4629_row0_col12 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_e4629_row1_col0 {
#   background-color: #dbdaeb;
#   color: #000000;
# }
# #T_e4629_row1_col7 {
#   background-color: #97b7d7;
#   color: #000000;
# }
# #T_e4629_row1_col10 {
#   background-color: #8cb3d5;
#   color: #000000;
# }
# #T_e4629_row1_col11 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_e4629_row2_col0 {
#   background-color: #9cb9d9;
#   color: #000000;
# }
# #T_e4629_row2_col6 {
#   background-color: #cdd0e5;
#   color: #000000;
# }
# #T_e4629_row2_col7 {
#   background-color: #2d8abd;
#   color: #f1f1f1;
# }
# #T_e4629_row2_col8 {
#   background-color: #d2d3e7;
#   color: #000000;
# }
# #T_e4629_row2_col9 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# #T_e4629_row2_col10 {
#   background-color: #2c89bd;
#   color: #f1f1f1;
# }
# #T_e4629_row2_col11 {
#   background-color: #dedcec;
#   color: #000000;
# }
# #T_e4629_row2_col12 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_e4629_row3_col0 {
#   background-color: #4295c3;
#   color: #f1f1f1;
# }
# #T_e4629_row3_col6 {
#   background-color: #3b92c1;
#   color: #f1f1f1;
# }
# #T_e4629_row3_col7, #T_e4629_row4_col0 {
#   background-color: #0567a2;
#   color: #f1f1f1;
# }
# #T_e4629_row3_col8 {
#   background-color: #63a2cb;
#   color: #f1f1f1;
# }
# #T_e4629_row3_col9 {
#   background-color: #6da6cd;
#   color: #f1f1f1;
# }
# #T_e4629_row3_col10 {
#   background-color: #0569a5;
#   color: #f1f1f1;
# }
# #T_e4629_row3_col11 {
#   background-color: #a5bddb;
#   color: #000000;
# }
# #T_e4629_row3_col12 {
#   background-color: #dddbec;
#   color: #000000;
# }
# #T_e4629_row4_col6, #T_e4629_row4_col9, #T_e4629_row5_col0, #T_e4629_row5_col7, #T_e4629_row5_col8, #T_e4629_row5_col10, #T_e4629_row5_col11, #T_e4629_row5_col12 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_e4629_row4_col7 {
#   background-color: #03476f;
#   color: #f1f1f1;
# }
# #T_e4629_row4_col8 {
#   background-color: #045280;
#   color: #f1f1f1;
# }
# #T_e4629_row4_col10 {
#   background-color: #045687;
#   color: #f1f1f1;
# }
# #T_e4629_row4_col11 {
#   background-color: #8fb4d6;
#   color: #000000;
# }
# #T_e4629_row4_col12 {
#   background-color: #a2bcda;
#   color: #000000;
# }
# #T_e4629_row5_col6 {
#   background-color: #023a5b;
#   color: #f1f1f1;
# }
# #T_e4629_row5_col9 {
#   background-color: #0d75b3;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_e4629">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e4629_level0_col0" class="col_heading level0 col0" >score</th>
#       <th id="T_e4629_level0_col1" class="col_heading level0 col1" >essay_id</th>
#       <th id="T_e4629_level0_col2" class="col_heading level0 col2" >full_text</th>
#       <th id="T_e4629_level0_col3" class="col_heading level0 col3" >prompt_name</th>
#       <th id="T_e4629_level0_col4" class="col_heading level0 col4" >kaggle_only</th>
#       <th id="T_e4629_level0_col5" class="col_heading level0 col5" >tokened_text</th>
#       <th id="T_e4629_level0_col6" class="col_heading level0 col6" >Lead_count</th>
#       <th id="T_e4629_level0_col7" class="col_heading level0 col7" >Position_count</th>
#       <th id="T_e4629_level0_col8" class="col_heading level0 col8" >Claim_count</th>
#       <th id="T_e4629_level0_col9" class="col_heading level0 col9" >Evidence_count</th>
#       <th id="T_e4629_level0_col10" class="col_heading level0 col10" >Concluding Statement_count</th>
#       <th id="T_e4629_level0_col11" class="col_heading level0 col11" >Counterclaim_count</th>
#       <th id="T_e4629_level0_col12" class="col_heading level0 col12" >Rebuttal_count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e4629_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e4629_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_e4629_row0_col1" class="data row0 col1" >None</td>
#       <td id="T_e4629_row0_col2" class="data row0 col2" >None</td>
#       <td id="T_e4629_row0_col3" class="data row0 col3" >None</td>
#       <td id="T_e4629_row0_col4" class="data row0 col4" >1.000000</td>
#       <td id="T_e4629_row0_col5" class="data row0 col5" >None</td>
#       <td id="T_e4629_row0_col6" class="data row0 col6" >0.345277</td>
#       <td id="T_e4629_row0_col7" class="data row0 col7" >0.657980</td>
#       <td id="T_e4629_row0_col8" class="data row0 col8" >2.762215</td>
#       <td id="T_e4629_row0_col9" class="data row0 col9" >2.771987</td>
#       <td id="T_e4629_row0_col10" class="data row0 col10" >0.364821</td>
#       <td id="T_e4629_row0_col11" class="data row0 col11" >0.192182</td>
#       <td id="T_e4629_row0_col12" class="data row0 col12" >0.244300</td>
#     </tr>
#     <tr>
#       <th id="T_e4629_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e4629_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_e4629_row1_col1" class="data row1 col1" >None</td>
#       <td id="T_e4629_row1_col2" class="data row1 col2" >None</td>
#       <td id="T_e4629_row1_col3" class="data row1 col3" >None</td>
#       <td id="T_e4629_row1_col4" class="data row1 col4" >1.000000</td>
#       <td id="T_e4629_row1_col5" class="data row1 col5" >None</td>
#       <td id="T_e4629_row1_col6" class="data row1 col6" >0.331355</td>
#       <td id="T_e4629_row1_col7" class="data row1 col7" >1.213650</td>
#       <td id="T_e4629_row1_col8" class="data row1 col8" >2.761622</td>
#       <td id="T_e4629_row1_col9" class="data row1 col9" >2.176063</td>
#       <td id="T_e4629_row1_col10" class="data row1 col10" >0.497527</td>
#       <td id="T_e4629_row1_col11" class="data row1 col11" >0.291790</td>
#       <td id="T_e4629_row1_col12" class="data row1 col12" >0.237389</td>
#     </tr>
#     <tr>
#       <th id="T_e4629_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e4629_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_e4629_row2_col1" class="data row2 col1" >None</td>
#       <td id="T_e4629_row2_col2" class="data row2 col2" >None</td>
#       <td id="T_e4629_row2_col3" class="data row2 col3" >None</td>
#       <td id="T_e4629_row2_col4" class="data row2 col4" >1.000000</td>
#       <td id="T_e4629_row2_col5" class="data row2 col5" >None</td>
#       <td id="T_e4629_row2_col6" class="data row2 col6" >0.401556</td>
#       <td id="T_e4629_row2_col7" class="data row2 col7" >1.524237</td>
#       <td id="T_e4629_row2_col8" class="data row2 col8" >3.737882</td>
#       <td id="T_e4629_row2_col9" class="data row2 col9" >2.979653</td>
#       <td id="T_e4629_row2_col10" class="data row2 col10" >0.561341</td>
#       <td id="T_e4629_row2_col11" class="data row2 col11" >0.395572</td>
#       <td id="T_e4629_row2_col12" class="data row2 col12" >0.344704</td>
#     </tr>
#     <tr>
#       <th id="T_e4629_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e4629_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_e4629_row3_col1" class="data row3 col1" >None</td>
#       <td id="T_e4629_row3_col2" class="data row3 col2" >None</td>
#       <td id="T_e4629_row3_col3" class="data row3 col3" >None</td>
#       <td id="T_e4629_row3_col4" class="data row3 col4" >1.000000</td>
#       <td id="T_e4629_row3_col5" class="data row3 col5" >None</td>
#       <td id="T_e4629_row3_col6" class="data row3 col6" >0.498075</td>
#       <td id="T_e4629_row3_col7" class="data row3 col7" >1.728253</td>
#       <td id="T_e4629_row3_col8" class="data row3 col8" >4.912240</td>
#       <td id="T_e4629_row3_col9" class="data row3 col9" >3.934565</td>
#       <td id="T_e4629_row3_col10" class="data row3 col10" >0.602771</td>
#       <td id="T_e4629_row3_col11" class="data row3 col11" >0.597383</td>
#       <td id="T_e4629_row3_col12" class="data row3 col12" >0.500385</td>
#     </tr>
#     <tr>
#       <th id="

# %%
dt_map
# Out:
# {'Lead': 0,
#  'Position': 1,
#  'Claim': 2,
#  'Evidence': 3,
#  'Concluding Statement': 4,
#  'Counterclaim': 5,
#  'Rebuttal': 6,
#  'Repeated': -1}

# %%
combined_token.write_csv('train_combined_tokened.csv')

# %% [markdown]
# # ALL DT Predcited from D012

# %%
all_dt_pred = pl.read_parquet('/kaggle/input/lal-aes2-infer-discourse-ds/all_dt_pred.parquet')
all_pred = softmax(all_dt_pred.select([f'pred_class_{c}' for c in range(7)]).to_numpy(), axis=-1).argmax(-1)
all_dt_pred = pl.concat([all_dt_pred, pl.DataFrame({'preds': all_pred})], how='horizontal')
all_dt_pred
# Out:
# shape: (326_053, 14)
# ┌────────────┬─────────────┬────────────┬───────┬───┬────────────┬────────────┬────────────┬───────┐
# │ essay_id   ┆ full_text   ┆ prompt_nam ┆ score ┆ … ┆ pred_class ┆ pred_class ┆ pred_class ┆ preds │
# │ ---        ┆ ---         ┆ e          ┆ ---   ┆   ┆ _4         ┆ _5         ┆ _6         ┆ ---   │
# │ str        ┆ str         ┆ ---        ┆ i64   ┆   ┆ ---        ┆ ---        ┆ ---        ┆ i64   │
# │            ┆             ┆ str        ┆       ┆   ┆ f32        ┆ f32        ┆ f32        ┆       │
# ╞════════════╪═════════════╪════════════╪═══════╪═══╪════════════╪════════════╪════════════╪═══════╡
# │ 000d118_0  ┆ Many people ┆ Car-free   ┆ 3     ┆ … ┆ -2.593693  ┆ -1.103083  ┆ -2.095595  ┆ 2     │
# │            ┆ have car    ┆ cities     ┆       ┆   ┆            ┆            ┆            ┆       │
# │            ┆ where they  ┆            ┆       ┆   ┆            ┆            ┆            ┆       │
# │            ┆ …           ┆            ┆       ┆   ┆            ┆            ┆            ┆       │
# │ 000d118_1  ┆ Many people ┆ Car-free   ┆ 3     ┆ … ┆ -1.821408  ┆ -0.223503  ┆ 0.909058   ┆ 3     │
# │            ┆ have car    ┆ cities     ┆       ┆   ┆            ┆            ┆            ┆       │
# │            ┆ where they  ┆            ┆       ┆   ┆            ┆            ┆            ┆       │
# │            ┆ …           ┆            ┆       ┆   ┆            ┆            ┆            ┆       │
# │ 000d118_2  ┆ Many people ┆ Car-free   ┆ 3     ┆ … ┆ -1.916697  ┆ -2.047137  ┆ -1.346176  ┆ 3     │
# │            ┆ have car    ┆ cities     ┆       ┆   ┆            ┆            ┆            ┆       │
# │            ┆ where they  ┆            ┆       ┆   ┆            ┆            ┆            ┆       │
# │            ┆ …           ┆            ┆       ┆   ┆            ┆            ┆            ┆       │
# │ 000d118_3  ┆ Many people ┆ Car-free   ┆ 3     ┆ … ┆ -1.528462  ┆ -1.853261  ┆ -0.455074  ┆ 3     │
# │            ┆ have car    ┆ cities     ┆       ┆   ┆            ┆            ┆            ┆       │
# │            ┆ where they  ┆            ┆       ┆   ┆            ┆            ┆            ┆       │
# │            ┆ …           ┆            ┆       ┆   ┆            ┆            ┆            ┆       │
# │ 000d118_4  ┆ Many people ┆ Car-free   ┆ 3     ┆ … ┆ -1.5447    ┆ -1.42729   ┆ 0.498887   ┆ 3     │
# │            ┆ have car    ┆ cities     ┆       ┆   ┆            ┆            ┆            ┆       │
# │            ┆ where they  ┆            ┆       ┆   ┆            ┆            ┆            ┆       │
# │            ┆ …           ┆            ┆       ┆   ┆            ┆            ┆            ┆       │
# │ …          ┆ …           ┆ …          ┆ …     ┆ … ┆ …          ┆ …          ┆ …          ┆ …     │
# │ fffed3e_7  ┆ Venus is    ┆ Exploring  ┆ 2     ┆ … ┆ -1.769132  ┆ -2.329039  ┆ -0.179665  ┆ 2     │
# │            ┆ worthy      ┆ Venus      ┆       ┆   ┆            ┆            ┆            ┆       │
# │            ┆ place to    ┆            ┆       ┆   ┆            ┆            ┆            ┆       │
# │            ┆ study b…    ┆            ┆       ┆   ┆            ┆            ┆            ┆       │
# │ fffed3e_8  ┆ Venus is    ┆ Exploring  ┆ 2     ┆ … ┆ -1.974055  ┆ -1.822579  ┆ -0.801626  ┆ 2     │
# │            ┆ worthy      ┆ Venus      ┆       ┆   ┆            ┆            ┆            ┆       │
# │            ┆ place to    ┆            ┆       ┆   ┆            ┆            ┆            ┆       │
# │            ┆ study b…    ┆            ┆       ┆   ┆            ┆            ┆            ┆       │
# │ fffed3e_9  ┆ Venus is    ┆ Exploring  ┆ 2     ┆ … ┆ -1.675161  ┆ 0.400315   ┆ 3.448996   ┆ 6     │
# │            ┆ worthy      ┆ Venus      ┆       ┆   ┆            ┆            ┆            ┆       │
# │            ┆ place to    ┆            ┆       ┆   ┆            ┆            ┆            ┆       │
# │            ┆ study b…    ┆            ┆       ┆   ┆            ┆            ┆            ┆       │
# │ fffed3e_10 ┆ Venus is    ┆ Exploring  ┆ 2     ┆ … ┆ -0.863772  ┆ -0.936937  ┆ 1.046222   ┆ 2     │
# │            ┆ worthy      ┆ Venus      ┆       ┆   ┆            ┆            ┆            ┆       │
# │            ┆ place to    ┆            ┆       ┆   ┆            ┆            ┆            ┆       │
# │            ┆ study b…    ┆            ┆       ┆   ┆            ┆            ┆            ┆       │
# │ fffed3e_11 ┆ Venus is    ┆ Exploring  ┆ 2     ┆ … ┆ 4.563483   ┆ -1.085738  ┆ -0.334294  ┆ 4     │
# │            ┆ worthy      ┆ Venus      ┆       ┆   ┆            ┆            ┆            ┆       │
# │            ┆ place to    ┆            ┆       ┆   ┆            ┆            ┆            ┆       │
# │            ┆ study b…    ┆            ┆       ┆   ┆            ┆            ┆            ┆       │
# └────────────┴─────────────┴────────────┴───────┴───┴────────────┴────────────┴────────────┴───────┘

# %%
new_repeated = []
for name, data in all_dt_pred.group_by(['full_text'], maintain_order=True):
    dtype = data['preds'].to_list()
    hold = -1
    for i in range(1, data.shape[0]):
#         if dtype[i] not in [1, 2]:
#             hold = dtype[i]
#             continue
        if dtype[i] == dtype[i - 1] or dtype[i] == hold:
            hold = dtype[i]
            dtype[i] = -1
    
    new_repeated.append(dtype)

# %%
all_dt_pred = all_dt_pred.with_columns(pl.Series(np.concatenate(new_repeated, axis=0)).alias('m_preds'))
all_dt_pred = all_dt_pred.with_columns(pl.col('m_preds').replace(rev_dt_map))
all_dt_pred = all_dt_pred.with_columns(pl.col('m_preds').replace(token_dt_map).alias('s_token'))
all_dt_pred = all_dt_pred.with_columns(pl.col('essay_id').str.replace_all('(_.*)', ''))
all_dt_pred = all_dt_pred.with_columns(pl.col('discourse_text').str.strip_chars(' ')).filter(pl.col('discourse_text') != '')
all_dt_pred
# Out:
# shape: (326_053, 16)
# ┌──────────┬─────────────┬─────────────┬───────┬───┬─────────────┬───────┬────────────┬────────────┐
# │ essay_id ┆ full_text   ┆ prompt_name ┆ score ┆ … ┆ pred_class_ ┆ preds ┆ m_preds    ┆ s_token    │
# │ ---      ┆ ---         ┆ ---         ┆ ---   ┆   ┆ 6           ┆ ---   ┆ ---        ┆ ---        │
# │ str      ┆ str         ┆ str         ┆ i64   ┆   ┆ ---         ┆ i64   ┆ str        ┆ str        │
# │          ┆             ┆             ┆       ┆   ┆ f32         ┆       ┆            ┆            │
# ╞══════════╪═════════════╪═════════════╪═══════╪═══╪═════════════╪═══════╪════════════╪════════════╡
# │ 000d118  ┆ Many people ┆ Car-free    ┆ 3     ┆ … ┆ -2.095595   ┆ 2     ┆ Claim      ┆ <Claim>    │
# │          ┆ have car    ┆ cities      ┆       ┆   ┆             ┆       ┆            ┆            │
# │          ┆ where they  ┆             ┆       ┆   ┆             ┆       ┆            ┆            │
# │          ┆ …           ┆             ┆       ┆   ┆             ┆       ┆            ┆            │
# │ 000d118  ┆ Many people ┆ Car-free    ┆ 3     ┆ … ┆ 0.909058    ┆ 3     ┆ Evidence   ┆ <Evidence> │
# │          ┆ have car    ┆ cities      ┆       ┆   ┆             ┆       ┆            ┆            │
# │          ┆ where they  ┆             ┆       ┆   ┆             ┆       ┆            ┆            │
# │          ┆ …           ┆             ┆       ┆   ┆             ┆       ┆            ┆            │
# │ 000d118  ┆ Many people ┆ Car-free    ┆ 3     ┆ … ┆ -1.346176   ┆ 3     ┆ Repeated   ┆            │
# │          ┆ have car    ┆ cities      ┆       ┆   ┆             ┆       ┆            ┆            │
# │          ┆ where they  ┆             ┆       ┆   ┆             ┆       ┆            ┆            │
# │          ┆ …           ┆             ┆       ┆   ┆             ┆       ┆            ┆            │
# │ 000d118  ┆ Many people ┆ Car-free    ┆ 3     ┆ … ┆ -0.455074   ┆ 3     ┆ Repeated   ┆            │
# │          ┆ have car    ┆ cities      ┆       ┆   ┆             ┆       ┆            ┆            │
# │          ┆ where they  ┆             ┆       ┆   ┆             ┆       ┆            ┆            │
# │          ┆ …           ┆             ┆       ┆   ┆             ┆       ┆            ┆            │
# │ 000d118  ┆ Many people ┆ Car-free    ┆ 3     ┆ … ┆ 0.498887    ┆ 3     ┆ Repeated   ┆            │
# │          ┆ have car    ┆ cities      ┆       ┆   ┆             ┆       ┆            ┆            │
# │          ┆ where they  ┆             ┆       ┆   ┆             ┆       ┆            ┆            │
# │          ┆ …           ┆             ┆       ┆   ┆             ┆       ┆            ┆            │
# │ …        ┆ …           ┆ …           ┆ …     ┆ … ┆ …           ┆ …     ┆ …          ┆ …          │
# │ fffed3e  ┆ Venus is    ┆ Exploring   ┆ 2     ┆ … ┆ -0.179665   ┆ 2     ┆ Repeated   ┆            │
# │          ┆ worthy      ┆ Venus       ┆       ┆   ┆             ┆       ┆            ┆            │
# │          ┆ place to    ┆             ┆       ┆   ┆             ┆       ┆            ┆            │
# │          ┆ study b…    ┆             ┆       ┆   ┆             ┆       ┆            ┆            │
# │ fffed3e  ┆ Venus is    ┆ Exploring   ┆ 2     ┆ … ┆ -0.801626   ┆ 2     ┆ Repeated   ┆            │
# │          ┆ worthy      ┆ Venus       ┆       ┆   ┆             ┆       ┆            ┆            │
# │          ┆ place to    ┆             ┆       ┆   ┆             ┆       ┆            ┆            │
# │          ┆ study b…    ┆             ┆       ┆   ┆             ┆       ┆            ┆            │
# │ fffed3e  ┆ Venus is    ┆ Exploring   ┆ 2     ┆ … ┆ 3.448996    ┆ 6     ┆ Rebuttal   ┆ <Rebuttal> │
# │          ┆ worthy      ┆ Venus       ┆       ┆   ┆             ┆       ┆            ┆            │
# │          ┆ place to    ┆             ┆       ┆   ┆             ┆       ┆            ┆            │
# │          ┆ study b…    ┆             ┆       ┆   ┆             ┆       ┆            ┆            │
# │ fffed3e  ┆ Venus is    ┆ Exploring   ┆ 2     ┆ … ┆ 1.046222    ┆ 2     ┆ Repeated   ┆            │
# │          ┆ worthy      ┆ Venus       ┆       ┆   ┆             ┆       ┆            ┆            │
# │          ┆ place to    ┆             ┆       ┆   ┆             ┆       ┆            ┆            │
# │          ┆ study b…    ┆             ┆       ┆   ┆             ┆       ┆            ┆            │
# │ fffed3e  ┆ Venus is    ┆ Exploring   ┆ 2     ┆ … ┆ -0.334294   ┆ 4     ┆ Concluding ┆ <Concludin │
# │          ┆ worthy      ┆ Venus       ┆       ┆   ┆             ┆       ┆ Statement  ┆ g>         │
# │          ┆ place to    ┆             ┆       ┆   ┆             ┆       ┆            ┆            │
# │          ┆ study b…    ┆             ┆       ┆   ┆             ┆       ┆            ┆            │
# └──────────┴─────────────┴─────────────┴───────┴───┴─────────────┴───────┴────────────┴────────────┘

# %%
new_s_token = []

for name, data in all_dt_pred.group_by(['essay_id', 'full_text'], maintain_order=True):

    rev_s_token = ','.join(data['s_token'].reverse().to_list())
    t_len = data.group_by("s_token").len()
    
    for k in t_len.to_dicts():
        if k['s_token'] == '<Lead>':
            if k['len'] > 1:
                lead_occur = rev_s_token.count('<Lead>')
                rev_s_token = rev_s_token.replace('<Lead>', '', lead_occur - 1)

    new_s_token.extend(reversed(rev_s_token.split(',')))

# %%
all_dt_pred = all_dt_pred.with_columns(new_s_token=pl.Series(new_s_token))
all_dt_pred
# Out:
# shape: (326_053, 17)
# ┌──────────┬─────────────┬─────────────┬───────┬───┬───────┬─────────────┬────────────┬────────────┐
# │ essay_id ┆ full_text   ┆ prompt_name ┆ score ┆ … ┆ preds ┆ m_preds     ┆ s_token    ┆ new_s_toke │
# │ ---      ┆ ---         ┆ ---         ┆ ---   ┆   ┆ ---   ┆ ---         ┆ ---        ┆ n          │
# │ str      ┆ str         ┆ str         ┆ i64   ┆   ┆ i64   ┆ str         ┆ str        ┆ ---        │
# │          ┆             ┆             ┆       ┆   ┆       ┆             ┆            ┆ str        │
# ╞══════════╪═════════════╪═════════════╪═══════╪═══╪═══════╪═════════════╪════════════╪════════════╡
# │ 000d118  ┆ Many people ┆ Car-free    ┆ 3     ┆ … ┆ 2     ┆ Claim       ┆ <Claim>    ┆ <Claim>    │
# │          ┆ have car    ┆ cities      ┆       ┆   ┆       ┆             ┆            ┆            │
# │          ┆ where they  ┆             ┆       ┆   ┆       ┆             ┆            ┆            │
# │          ┆ …           ┆             ┆       ┆   ┆       ┆             ┆            ┆            │
# │ 000d118  ┆ Many people ┆ Car-free    ┆ 3     ┆ … ┆ 3     ┆ Evidence    ┆ <Evidence> ┆ <Evidence> │
# │          ┆ have car    ┆ cities      ┆       ┆   ┆       ┆             ┆            ┆            │
# │          ┆ where they  ┆             ┆       ┆   ┆       ┆             ┆            ┆            │
# │          ┆ …           ┆             ┆       ┆   ┆       ┆             ┆            ┆            │
# │ 000d118  ┆ Many people ┆ Car-free    ┆ 3     ┆ … ┆ 3     ┆ Repeated    ┆            ┆            │
# │          ┆ have car    ┆ cities      ┆       ┆   ┆       ┆             ┆            ┆            │
# │          ┆ where they  ┆             ┆       ┆   ┆       ┆             ┆            ┆            │
# │          ┆ …           ┆             ┆       ┆   ┆       ┆             ┆            ┆            │
# │ 000d118  ┆ Many people ┆ Car-free    ┆ 3     ┆ … ┆ 3     ┆ Repeated    ┆            ┆            │
# │          ┆ have car    ┆ cities      ┆       ┆   ┆       ┆             ┆            ┆            │
# │          ┆ where they  ┆             ┆       ┆   ┆       ┆             ┆            ┆            │
# │          ┆ …           ┆             ┆       ┆   ┆       ┆             ┆            ┆            │
# │ 000d118  ┆ Many people ┆ Car-free    ┆ 3     ┆ … ┆ 3     ┆ Repeated    ┆            ┆            │
# │          ┆ have car    ┆ cities      ┆       ┆   ┆       ┆             ┆            ┆            │
# │          ┆ where they  ┆             ┆       ┆   ┆       ┆             ┆            ┆            │
# │          ┆ …           ┆             ┆       ┆   ┆       ┆             ┆            ┆            │
# │ …        ┆ …           ┆ …           ┆ …     ┆ … ┆ …     ┆ …           ┆ …          ┆ …          │
# │ fffed3e  ┆ Venus is    ┆ Exploring   ┆ 2     ┆ … ┆ 2     ┆ Repeated    ┆            ┆            │
# │          ┆ worthy      ┆ Venus       ┆       ┆   ┆       ┆             ┆            ┆            │
# │          ┆ place to    ┆             ┆       ┆   ┆       ┆             ┆            ┆            │
# │          ┆ study b…    ┆             ┆       ┆   ┆       ┆             ┆            ┆            │
# │ fffed3e  ┆ Venus is    ┆ Exploring   ┆ 2     ┆ … ┆ 2     ┆ Repeated    ┆            ┆            │
# │          ┆ worthy      ┆ Venus       ┆       ┆   ┆       ┆             ┆            ┆            │
# │          ┆ place to    ┆             ┆       ┆   ┆       ┆             ┆            ┆            │
# │          ┆ study b…    ┆             ┆       ┆   ┆       ┆             ┆            ┆            │
# │ fffed3e  ┆ Venus is    ┆ Exploring   ┆ 2     ┆ … ┆ 6     ┆ Rebuttal    ┆ <Rebuttal> ┆ <Rebuttal> │
# │          ┆ worthy      ┆ Venus       ┆       ┆   ┆       ┆             ┆            ┆            │
# │          ┆ place to    ┆             ┆       ┆   ┆       ┆             ┆            ┆            │
# │          ┆ study b…    ┆             ┆       ┆   ┆       ┆             ┆            ┆            │
# │ fffed3e  ┆ Venus is    ┆ Exploring   ┆ 2     ┆ … ┆ 2     ┆ Repeated    ┆            ┆            │
# │          ┆ worthy      ┆ Venus       ┆       ┆   ┆       ┆             ┆            ┆            │
# │          ┆ place to    ┆             ┆       ┆   ┆       ┆             ┆            ┆            │
# │          ┆ study b…    ┆             ┆       ┆   ┆       ┆             ┆            ┆            │
# │ fffed3e  ┆ Venus is    ┆ Exploring   ┆ 2     ┆ … ┆ 4     ┆ Concluding  ┆ <Concludin ┆ <Concludin │
# │          ┆ worthy      ┆ Venus       ┆       ┆   ┆       ┆ Statement   ┆ g>         ┆ g>         │
# │          ┆ place to    ┆             ┆       ┆   ┆       ┆             ┆            ┆            │
# │          ┆ study b…    ┆             ┆       ┆   ┆       ┆             ┆            ┆            │
# └──────────┴─────────────┴─────────────┴───────┴───┴───────┴─────────────┴────────────┴────────────┘

# %%
new_s_token = []

for name, data in all_dt_pred.group_by(['essay_id', 'full_text'], maintain_order=True):

    rev_s_token = ','.join(data['new_s_token'].to_list())
    t_len = data.group_by("new_s_token").len()
    
    for k in t_len.to_dicts():
        if k['new_s_token'] == '<Concluding>':
            if k['len'] > 1:
                conclude_occur = rev_s_token.count('<Concluding>')
                rev_s_token = rev_s_token.replace('<Concluding>', '', conclude_occur - 1)

    new_s_token.extend(rev_s_token.split(','))

# %%
all_dt_pred = all_dt_pred.with_columns(new_s_token=pl.Series(new_s_token))
all_dt_pred
# Out:
# shape: (326_053, 17)
# ┌──────────┬─────────────┬─────────────┬───────┬───┬───────┬─────────────┬────────────┬────────────┐
# │ essay_id ┆ full_text   ┆ prompt_name ┆ score ┆ … ┆ preds ┆ m_preds     ┆ s_token    ┆ new_s_toke │
# │ ---      ┆ ---         ┆ ---         ┆ ---   ┆   ┆ ---   ┆ ---         ┆ ---        ┆ n          │
# │ str      ┆ str         ┆ str         ┆ i64   ┆   ┆ i64   ┆ str         ┆ str        ┆ ---        │
# │          ┆             ┆             ┆       ┆   ┆       ┆             ┆            ┆ str        │
# ╞══════════╪═════════════╪═════════════╪═══════╪═══╪═══════╪═════════════╪════════════╪════════════╡
# │ 000d118  ┆ Many people ┆ Car-free    ┆ 3     ┆ … ┆ 2     ┆ Claim       ┆ <Claim>    ┆ <Claim>    │
# │          ┆ have car    ┆ cities      ┆       ┆   ┆       ┆             ┆            ┆            │
# │          ┆ where they  ┆             ┆       ┆   ┆       ┆             ┆            ┆            │
# │          ┆ …           ┆             ┆       ┆   ┆       ┆             ┆            ┆            │
# │ 000d118  ┆ Many people ┆ Car-free    ┆ 3     ┆ … ┆ 3     ┆ Evidence    ┆ <Evidence> ┆ <Evidence> │
# │          ┆ have car    ┆ cities      ┆       ┆   ┆       ┆             ┆            ┆            │
# │          ┆ where they  ┆             ┆       ┆   ┆       ┆             ┆            ┆            │
# │          ┆ …           ┆             ┆       ┆   ┆       ┆             ┆            ┆            │
# │ 000d118  ┆ Many people ┆ Car-free    ┆ 3     ┆ … ┆ 3     ┆ Repeated    ┆            ┆            │
# │          ┆ have car    ┆ cities      ┆       ┆   ┆       ┆             ┆            ┆            │
# │          ┆ where they  ┆             ┆       ┆   ┆       ┆             ┆            ┆            │
# │          ┆ …           ┆             ┆       ┆   ┆       ┆             ┆            ┆            │
# │ 000d118  ┆ Many people ┆ Car-free    ┆ 3     ┆ … ┆ 3     ┆ Repeated    ┆            ┆            │
# │          ┆ have car    ┆ cities      ┆       ┆   ┆       ┆             ┆            ┆            │
# │          ┆ where they  ┆             ┆       ┆   ┆       ┆             ┆            ┆            │
# │          ┆ …           ┆             ┆       ┆   ┆       ┆             ┆            ┆            │
# │ 000d118  ┆ Many people ┆ Car-free    ┆ 3     ┆ … ┆ 3     ┆ Repeated    ┆            ┆            │
# │          ┆ have car    ┆ cities      ┆       ┆   ┆       ┆             ┆            ┆            │
# │          ┆ where they  ┆             ┆       ┆   ┆       ┆             ┆            ┆            │
# │          ┆ …           ┆             ┆       ┆   ┆       ┆             ┆            ┆            │
# │ …        ┆ …           ┆ …           ┆ …     ┆ … ┆ …     ┆ …           ┆ …          ┆ …          │
# │ fffed3e  ┆ Venus is    ┆ Exploring   ┆ 2     ┆ … ┆ 2     ┆ Repeated    ┆            ┆            │
# │          ┆ worthy      ┆ Venus       ┆       ┆   ┆       ┆             ┆            ┆            │
# │          ┆ place to    ┆             ┆       ┆   ┆       ┆             ┆            ┆            │
# │          ┆ study b…    ┆             ┆       ┆   ┆       ┆             ┆            ┆            │
# │ fffed3e  ┆ Venus is    ┆ Exploring   ┆ 2     ┆ … ┆ 2     ┆ Repeated    ┆            ┆            │
# │          ┆ worthy      ┆ Venus       ┆       ┆   ┆       ┆             ┆            ┆            │
# │          ┆ place to    ┆             ┆       ┆   ┆       ┆             ┆            ┆            │
# │          ┆ study b…    ┆             ┆       ┆   ┆       ┆             ┆            ┆            │
# │ fffed3e  ┆ Venus is    ┆ Exploring   ┆ 2     ┆ … ┆ 6     ┆ Rebuttal    ┆ <Rebuttal> ┆ <Rebuttal> │
# │          ┆ worthy      ┆ Venus       ┆       ┆   ┆       ┆             ┆            ┆            │
# │          ┆ place to    ┆             ┆       ┆   ┆       ┆             ┆            ┆            │
# │          ┆ study b…    ┆             ┆       ┆   ┆       ┆             ┆            ┆            │
# │ fffed3e  ┆ Venus is    ┆ Exploring   ┆ 2     ┆ … ┆ 2     ┆ Repeated    ┆            ┆            │
# │          ┆ worthy      ┆ Venus       ┆       ┆   ┆       ┆             ┆            ┆            │
# │          ┆ place to    ┆             ┆       ┆   ┆       ┆             ┆            ┆            │
# │          ┆ study b…    ┆             ┆       ┆   ┆       ┆             ┆            ┆            │
# │ fffed3e  ┆ Venus is    ┆ Exploring   ┆ 2     ┆ … ┆ 4     ┆ Concluding  ┆ <Concludin ┆ <Concludin │
# │          ┆ worthy      ┆ Venus       ┆       ┆   ┆       ┆ Statement   ┆ g>         ┆ g>         │
# │          ┆ place to    ┆             ┆       ┆   ┆       ┆             ┆            ┆            │
# │          ┆ study b…    ┆             ┆       ┆   ┆       ┆             ┆            ┆            │
# └──────────┴─────────────┴─────────────┴───────┴───┴───────┴─────────────┴────────────┴────────────┘

# %%
all_sen = all_dt_pred.with_columns(pl.concat_str([pl.col('new_s_token'), pl.col('discourse_text')], separator="").alias('tokened_text'))
all_sen = all_sen.group_by(selected_cols, maintain_order=True).agg([
    pl.col('tokened_text').str.concat(' ')
])
all_sen = all_sen.with_columns(pl.col('tokened_text').str.replace_all(pat_1, pat_2))
all_sen
# Out:
# shape: (17_305, 6)
# ┌──────────┬─────────────────────┬─────────────────────┬───────┬─────────────┬─────────────────────┐
# │ essay_id ┆ full_text           ┆ prompt_name         ┆ score ┆ kaggle_only ┆ tokened_text        │
# │ ---      ┆ ---                 ┆ ---                 ┆ ---   ┆ ---         ┆ ---                 │
# │ str      ┆ str                 ┆ str                 ┆ i64   ┆ bool        ┆ str                 │
# ╞══════════╪═════════════════════╪═════════════════════╪═══════╪═════════════╪═════════════════════╡
# │ 000d118  ┆ Many people have    ┆ Car-free cities     ┆ 3     ┆ false       ┆ <Claim>Many people  │
# │          ┆ car where they …    ┆                     ┆       ┆             ┆ have car wher…      │
# │ 000fe60  ┆ I am a scientist at ┆ The Face on Mars    ┆ 3     ┆ true        ┆ <Lead>I am a        │
# │          ┆ NASA that is…       ┆                     ┆       ┆             ┆ scientist at NASA   │
# │          ┆                     ┆                     ┆       ┆             ┆ t…                  │
# │ 001ab80  ┆ People always wish  ┆ Driverless cars     ┆ 4     ┆ true        ┆ <Claim>People       │
# │          ┆ they had the …      ┆                     ┆       ┆             ┆ always wish they h… │
# │ 001bdc0  ┆ We all heard about  ┆ Exploring Venus     ┆ 4     ┆ true        ┆ <Lead>We all heard  │
# │          ┆ Venus, the pl…      ┆                     ┆       ┆             ┆ about Venus, …      │
# │ 002ba53  ┆ Dear, State Senator ┆ Does the electoral  ┆ 3     ┆ false       ┆ <Position>Dear,     │
# │          ┆                     ┆ college work?       ┆       ┆             ┆ State Senator       │
# │          ┆ This is a l…        ┆                     ┆       ┆             ┆                     │
# │          ┆                     ┆                     ┆       ┆             ┆ T…                  │
# │ …        ┆ …                   ┆ …                   ┆ …     ┆ …           ┆ …                   │
# │ ffd378d  ┆ the story " The     ┆ Exploring Venus     ┆ 2     ┆ true        ┆ <Lead>the story "   │
# │          ┆ Challenge of Exp…   ┆                     ┆       ┆             ┆ The Challenge …     │
# │ ffddf1f  ┆ Technology has      ┆ Facial action       ┆ 4     ┆ false       ┆ <Claim>Technology   │
# │          ┆ changed a lot of …  ┆ coding system       ┆       ┆             ┆ has changed a …     │
# │ fff016d  ┆ If you don't like   ┆ "A Cowboy Who Rode  ┆ 2     ┆ false       ┆ <Claim>If you don't │
# │          ┆ sitting around…     ┆ the Waves"          ┆       ┆             ┆ like sitting…       │
# │ fffb49b  ┆ In "The Challenge   ┆ Exploring Venus     ┆ 1     ┆ false       ┆ <Lead>In "The       │
# │          ┆ of Exporing Ve…     ┆                     ┆       ┆             ┆ Challenge of Expor… │
# │ fffed3e  ┆ Venus is worthy     ┆ Exploring Venus     ┆ 2     ┆ true        ┆ <Position>Venus is  │
# │          ┆ place to study b…   ┆                     ┆       ┆             ┆ worthy place …      │
# └──────────┴─────────────────────┴─────────────────────┴───────┴─────────────┴─────────────────────┘

# %%
tt = all_sen.with_columns([pl.col('tokened_text').str.count_matches(count_dt[i]).alias(f'{rev_dt_map[i]}' +'_count') for i in range(7)]).group_by(['score']).mean().sort('score')
tt.to_pandas().style.background_gradient()
# Out:
# <style type="text/css">
# #T_6ce6e_row0_col0, #T_6ce6e_row0_col7, #T_6ce6e_row0_col10, #T_6ce6e_row0_col11, #T_6ce6e_row1_col6, #T_6ce6e_row1_col8, #T_6ce6e_row1_col9, #T_6ce6e_row1_col12, #T_6ce6e_row5_col4 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_6ce6e_row0_col4, #T_6ce6e_row4_col11 {
#   background-color: #328dbf;
#   color: #f1f1f1;
# }
# #T_6ce6e_row0_col6 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_6ce6e_row0_col8, #T_6ce6e_row2_col12 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_6ce6e_row0_col9 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_6ce6e_row0_col12 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_6ce6e_row1_col0 {
#   background-color: #dbdaeb;
#   color: #000000;
# }
# #T_6ce6e_row1_col4 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_6ce6e_row1_col7 {
#   background-color: #99b8d8;
#   color: #000000;
# }
# #T_6ce6e_row1_col10 {
#   background-color: #8eb3d5;
#   color: #000000;
# }
# #T_6ce6e_row1_col11 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_6ce6e_row2_col0 {
#   background-color: #9cb9d9;
#   color: #000000;
# }
# #T_6ce6e_row2_col4 {
#   background-color: #0f76b3;
#   color: #f1f1f1;
# }
# #T_6ce6e_row2_col6 {
#   background-color: #bcc7e1;
#   color: #000000;
# }
# #T_6ce6e_row2_col7 {
#   background-color: #2d8abd;
#   color: #f1f1f1;
# }
# #T_6ce6e_row2_col8 {
#   background-color: #cacee5;
#   color: #000000;
# }
# #T_6ce6e_row2_col9 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_6ce6e_row2_col10, #T_6ce6e_row3_col8 {
#   background-color: #4c99c5;
#   color: #f1f1f1;
# }
# #T_6ce6e_row2_col11 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_6ce6e_row3_col0 {
#   background-color: #4295c3;
#   color: #f1f1f1;
# }
# #T_6ce6e_row3_col4, #T_6ce6e_row5_col0, #T_6ce6e_row5_col6, #T_6ce6e_row5_col7, #T_6ce6e_row5_col8, #T_6ce6e_row5_col9, #T_6ce6e_row5_col10, #T_6ce6e_row5_col11, #T_6ce6e_row5_col12 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_6ce6e_row3_col6 {
#   background-color: #348ebf;
#   color: #f1f1f1;
# }
# #T_6ce6e_row3_col7 {
#   background-color: #0568a3;
#   color: #f1f1f1;
# }
# #T_6ce6e_row3_col9 {
#   background-color: #84b0d3;
#   color: #f1f1f1;
# }
# #T_6ce6e_row3_col10 {
#   background-color: #1077b4;
#   color: #f1f1f1;
# }
# #T_6ce6e_row3_col11 {
#   background-color: #9ab8d8;
#   color: #000000;
# }
# #T_6ce6e_row3_col12 {
#   background-color: #d7d6e9;
#   color: #000000;
# }
# #T_6ce6e_row4_col0 {
#   background-color: #0567a2;
#   color: #f1f1f1;
# }
# #T_6ce6e_row4_col4 {
#   background-color: #e3e0ee;
#   color: #000000;
# }
# #T_6ce6e_row4_col6 {
#   background-color: #045e93;
#   color: #f1f1f1;
# }
# #T_6ce6e_row4_col7 {
#   background-color: #023b5d;
#   color: #f1f1f1;
# }
# #T_6ce6e_row4_col8 {
#   background-color: #03446a;
#   color: #f1f1f1;
# }
# #T_6ce6e_row4_col9 {
#   background-color: #0569a5;
#   color: #f1f1f1;
# }
# #T_6ce6e_row4_col10 {
#   background-color: #05659f;
#   color: #f1f1f1;
# }
# #T_6ce6e_row4_col12 {
#   background-color: #6fa7ce;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6ce6e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6ce6e_level0_col0" class="col_heading level0 col0" >score</th>
#       <th id="T_6ce6e_level0_col1" class="col_heading level0 col1" >essay_id</th>
#       <th id="T_6ce6e_level0_col2" class="col_heading level0 col2" >full_text</th>
#       <th id="T_6ce6e_level0_col3" class="col_heading level0 col3" >prompt_name</th>
#       <th id="T_6ce6e_level0_col4" class="col_heading level0 col4" >kaggle_only</th>
#       <th id="T_6ce6e_level0_col5" class="col_heading level0 col5" >tokened_text</th>
#       <th id="T_6ce6e_level0_col6" class="col_heading level0 col6" >Lead_count</th>
#       <th id="T_6ce6e_level0_col7" class="col_heading level0 col7" >Position_count</th>
#       <th id="T_6ce6e_level0_col8" class="col_heading level0 col8" >Claim_count</th>
#       <th id="T_6ce6e_level0_col9" class="col_heading level0 col9" >Evidence_count</th>
#       <th id="T_6ce6e_level0_col10" class="col_heading level0 col10" >Concluding Statement_count</th>
#       <th id="T_6ce6e_level0_col11" class="col_heading level0 col11" >Counterclaim_count</th>
#       <th id="T_6ce6e_level0_col12" class="col_heading level0 col12" >Rebuttal_count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6ce6e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6ce6e_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_6ce6e_row0_col1" class="data row0 col1" >None</td>
#       <td id="T_6ce6e_row0_col2" class="data row0 col2" >None</td>
#       <td id="T_6ce6e_row0_col3" class="data row0 col3" >None</td>
#       <td id="T_6ce6e_row0_col4" class="data row0 col4" >0.245208</td>
#       <td id="T_6ce6e_row0_col5" class="data row0 col5" >None</td>
#       <td id="T_6ce6e_row0_col6" class="data row0 col6" >0.354633</td>
#       <td id="T_6ce6e_row0_col7" class="data row0 col7" >0.653355</td>
#       <td id="T_6ce6e_row0_col8" class="data row0 col8" >2.046326</td>
#       <td id="T_6ce6e_row0_col9" class="data row0 col9" >2.177316</td>
#       <td id="T_6ce6e_row0_col10" class="data row0 col10" >0.369808</td>
#       <td id="T_6ce6e_row0_col11" class="data row0 col11" >0.172524</td>
#       <td id="T_6ce6e_row0_col12" class="data row0 col12" >0.279553</td>
#     </tr>
#     <tr>
#       <th id="T_6ce6e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6ce6e_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_6ce6e_row1_col1" class="data row1 col1" >None</td>
#       <td id="T_6ce6e_row1_col2" class="data row1 col2" >None</td>
#       <td id="T_6ce6e_row1_col3" class="data row1 col3" >None</td>
#       <td id="T_6ce6e_row1_col4" class="data row1 col4" >0.214059</td>
#       <td id="T_6ce6e_row1_col5" class="data row1 col5" >None</td>
#       <td id="T_6ce6e_row1_col6" class="data row1 col6" >0.344061</td>
#       <td id="T_6ce6e_row1_col7" class="data row1 col7" >1.236714</td>
#       <td id="T_6ce6e_row1_col8" class="data row1 col8" >1.919754</td>
#       <td id="T_6ce6e_row1_col9" class="data row1 col9" >1.785306</td>
#       <td id="T_6ce6e_row1_col10" class="data row1 col10" >0.519162</td>
#       <td id="T_6ce6e_row1_col11" class="data row1 col11" >0.267838</td>
#       <td id="T_6ce6e_row1_col12" class="data row1 col12" >0.253652</td>
#     </tr>
#     <tr>
#       <th id="T_6ce6e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6ce6e_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_6ce6e_row2_col1" class="data row2 col1" >None</td>
#       <td id="T_6ce6e_row2_col2" class="data row2 col2" >None</td>
#       <td id="T_6ce6e_row2_col3" class="data row2 col3" >None</td>
#       <td id="T_6ce6e_row2_col4" class="data row2 col4" >0.266168</td>
#       <td id="T_6ce6e_row2_col5" class="data row2 col5" >None</td>
#       <td id="T_6ce6e_row2_col6" class="data row2 col6" >0.428003</td>
#       <td id="T_6ce6e_row2_col7" class="data row2 col7" >1.577891</td>
#       <td id="T_6ce6e_row2_col8" class="data row2 col8" >2.266805</td>
#       <td id="T_6ce6e_row2_col9" class="data row2 col9" >2.351227</td>
#       <td id="T_6ce6e_row2_col10" class="data row2 col10" >0.568493</td>
#       <td id="T_6ce6e_row2_col11" class="data row2 col11" >0.381650</td>
#       <td id="T_6ce6e_row2_col12" class="data row2 col12" >0.365881</td>
#     </tr>
#     <tr>
#       <th id="T_6ce6e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6ce6e_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_6ce6e_row3_col1" class="data row3 col1" >None</td>
#       <td id="T_6ce6e_row3_col2" class="data row3 col2" >None</td>
#       <td id="T_6ce6e_row3_col3" class="data row3 col3" >None</td>
#       <td id="T_6ce6e_row3_col4" class="data row3 col4" >0.330871</td>
#       <td id="T_6ce6e_row3_col5" class="data row3 col5" >None</td>
#       <td id="T_6ce6e_row3_col6" class="data row3 col6" >0.515537</td>
#       <td id="T_6ce6e_row3_col7" class="data row3 col7" >1.789353</td>
#       <td id="T_6ce6e_row3_col8" class="data row3 col8" >2.677534</td>
#       <td id="T_6ce6e_row3_col9" class="data row3 col9" >3.046103</td>
#       <td id="T_6ce6e_row3_col10" class="data row3 col10" >0.615894</td>
#       <td id="T_6ce6e_row3_co

# %%
all_sen.write_csv('train_combined_tokened_D012.csv')

# %% [markdown]
# # Discourse type predictions from MLM

# %%
mlm_preds = pl.read_parquet('/kaggle/input/lal-aes2-infer-mlm/mlm_pred.parquet')
mlm_preds
# Out:
# shape: (17_305, 8)
# ┌──────────┬─────────────┬─────────────┬───────┬────────────┬────────────┬────────────┬────────────┐
# │ essay_id ┆ full_text   ┆ prompt_name ┆ score ┆ kaggle_onl ┆ masked     ┆ deberta_la ┆ preds      │
# │ ---      ┆ ---         ┆ ---         ┆ ---   ┆ y          ┆ ---        ┆ bels_idx   ┆ ---        │
# │ str      ┆ str         ┆ str         ┆ i64   ┆ ---        ┆ str        ┆ ---        ┆ list[i64]  │
# │          ┆             ┆             ┆       ┆ bool       ┆            ┆ list[i64]  ┆            │
# ╞══════════╪═════════════╪═════════════╪═══════╪════════════╪════════════╪════════════╪════════════╡
# │ 000d118  ┆ Many people ┆ Car-free    ┆ 3     ┆ false      ┆ [MASK]Many ┆ [1, 10, …  ┆ [128003,   │
# │          ┆ have car    ┆ cities      ┆       ┆            ┆ people     ┆ 596]       ┆ 128006, …  │
# │          ┆ where they  ┆             ┆       ┆            ┆ have car   ┆            ┆ 128004]    │
# │          ┆ …           ┆             ┆       ┆            ┆ where…     ┆            ┆            │
# │ 000fe60  ┆ I am a      ┆ The Face on ┆ 3     ┆ true       ┆ [MASK]I am ┆ [1, 18, …  ┆ [128003,   │
# │          ┆ scientist   ┆ Mars        ┆       ┆            ┆ a          ┆ 379]       ┆ 128004, …  │
# │          ┆ at NASA     ┆             ┆       ┆            ┆ scientist  ┆            ┆ 128007]    │
# │          ┆ that is…    ┆             ┆       ┆            ┆ at NASA t… ┆            ┆            │
# │ 001ab80  ┆ People      ┆ Driverless  ┆ 4     ┆ true       ┆ [MASK]Peop ┆ [1, 31, …  ┆ [128003,   │
# │          ┆ always wish ┆ cars        ┆       ┆            ┆ le always  ┆ 637]       ┆ 128004, …  │
# │          ┆ they had    ┆             ┆       ┆            ┆ wish they  ┆            ┆ 128007]    │
# │          ┆ the …       ┆             ┆       ┆            ┆ ha…        ┆            ┆            │
# │ 001bdc0  ┆ We all      ┆ Exploring   ┆ 4     ┆ true       ┆ [MASK]We   ┆ [1, 72, …  ┆ [128003,   │
# │          ┆ heard about ┆ Venus       ┆       ┆            ┆ all heard  ┆ 537]       ┆ 128005, …  │
# │          ┆ Venus, the  ┆             ┆       ┆            ┆ about      ┆            ┆ 128007]    │
# │          ┆ pl…         ┆             ┆       ┆            ┆ Venus, …   ┆            ┆            │
# │ 002ba53  ┆ Dear, State ┆ Does the    ┆ 3     ┆ false      ┆ [MASK]Dear ┆ [1, 20, …  ┆ [128003,   │
# │          ┆ Senator     ┆ electoral   ┆       ┆            ┆ , State    ┆ 455]       ┆ 128006, …  │
# │          ┆             ┆ college     ┆       ┆            ┆ Senator[PA ┆            ┆ 128007]    │
# │          ┆ This is a   ┆ work?       ┆       ┆            ┆ RAGR…      ┆            ┆            │
# │          ┆ l…          ┆             ┆       ┆            ┆            ┆            ┆            │
# │ …        ┆ …           ┆ …           ┆ …     ┆ …          ┆ …          ┆ …          ┆ …          │
# │ ffd378d  ┆ the story " ┆ Exploring   ┆ 2     ┆ true       ┆ [MASK]the  ┆ [1, 29, …  ┆ [128003,   │
# │          ┆ The         ┆ Venus       ┆       ┆            ┆ story "    ┆ 185]       ┆ 128005, …  │
# │          ┆ Challenge   ┆             ┆       ┆            ┆ The        ┆            ┆ 128007]    │
# │          ┆ of Exp…     ┆             ┆       ┆            ┆ Challenge  ┆            ┆            │
# │          ┆             ┆             ┆       ┆            ┆ …          ┆            ┆            │
# │ ffddf1f  ┆ Technology  ┆ Facial      ┆ 4     ┆ false      ┆ [MASK]Tech ┆ [1, 14, …  ┆ [128003,   │
# │          ┆ has changed ┆ action      ┆       ┆            ┆ nology has ┆ 682]       ┆ 128006, …  │
# │          ┆ a lot of …  ┆ coding      ┆       ┆            ┆ changed a  ┆            ┆ 128007]    │
# │          ┆             ┆ system      ┆       ┆            ┆ l…         ┆            ┆            │
# │ fff016d  ┆ If you      ┆ "A Cowboy   ┆ 2     ┆ false      ┆ [MASK]If   ┆ [1, 27, …  ┆ [128003,   │
# │          ┆ don't like  ┆ Who Rode    ┆       ┆            ┆ you don't  ┆ 249]       ┆ 128004, …  │
# │          ┆ sitting     ┆ the Waves"  ┆       ┆            ┆ like       ┆            ┆ 128007]    │
# │          ┆ around…     ┆             ┆       ┆            ┆ sitting …  ┆            ┆            │
# │ fffb49b  ┆ In "The     ┆ Exploring   ┆ 1     ┆ false      ┆ [MASK]In   ┆ [1, 46, …  ┆ [128004,   │
# │          ┆ Challenge   ┆ Venus       ┆       ┆            ┆ "The       ┆ 267]       ┆ 128006, …  │
# │          ┆ of Exporing ┆             ┆       ┆            ┆ Challenge  ┆            ┆ 128007]    │
# │          ┆ Ve…         ┆             ┆       ┆            ┆ of Expor…  ┆            ┆            │
# │ fffed3e  ┆ Venus is    ┆ Exploring   ┆ 2     ┆ true       ┆ [MASK]Venu ┆ [1, 11, …  ┆ [128004,   │
# │          ┆ worthy      ┆ Venus       ┆       ┆            ┆ s is       ┆ 167]       ┆ 128005, …  │
# │          ┆ place to    ┆             ┆       ┆            ┆ worthy     ┆            ┆ 128007]    │
# │          ┆ study b…    ┆             ┆       ┆            ┆ place to   ┆            ┆            │
# │          ┆             ┆             ┆       ┆            ┆ s…         ┆            ┆            │
# └──────────┴─────────────┴─────────────┴───────┴────────────┴────────────┴────────────┴────────────┘

# %%
new_repeated = []
for name, data in mlm_preds.explode('preds').group_by(['essay_id', 'full_text'], maintain_order=True):
    dtype = data['preds'].to_list()
    hold = -1
    for i in range(1, data.shape[0]):
        if dtype[i] == dtype[i - 1] or dtype[i] == hold:
            hold = dtype[i]
            dtype[i] = -1
    
    new_repeated.append(dtype)

# %%
tmp = mlm_preds.explode('preds').with_columns(preds=pl.Series(np.concatenate(new_repeated, axis=0)))
tmp = tmp.with_columns(pl.col('preds').replace(mlm_token_map, return_dtype=pl.String))
tmp
# Out:
# shape: (326_053, 8)
# ┌──────────┬─────────────┬─────────────┬───────┬────────────┬────────────┬────────────┬────────────┐
# │ essay_id ┆ full_text   ┆ prompt_name ┆ score ┆ kaggle_onl ┆ masked     ┆ deberta_la ┆ preds      │
# │ ---      ┆ ---         ┆ ---         ┆ ---   ┆ y          ┆ ---        ┆ bels_idx   ┆ ---        │
# │ str      ┆ str         ┆ str         ┆ i64   ┆ ---        ┆ str        ┆ ---        ┆ str        │
# │          ┆             ┆             ┆       ┆ bool       ┆            ┆ list[i64]  ┆            │
# ╞══════════╪═════════════╪═════════════╪═══════╪════════════╪════════════╪════════════╪════════════╡
# │ 000d118  ┆ Many people ┆ Car-free    ┆ 3     ┆ false      ┆ [MASK]Many ┆ [1, 10, …  ┆ <Lead>     │
# │          ┆ have car    ┆ cities      ┆       ┆            ┆ people     ┆ 596]       ┆            │
# │          ┆ where they  ┆             ┆       ┆            ┆ have car   ┆            ┆            │
# │          ┆ …           ┆             ┆       ┆            ┆ where…     ┆            ┆            │
# │ 000d118  ┆ Many people ┆ Car-free    ┆ 3     ┆ false      ┆ [MASK]Many ┆ [1, 10, …  ┆ <Evidence> │
# │          ┆ have car    ┆ cities      ┆       ┆            ┆ people     ┆ 596]       ┆            │
# │          ┆ where they  ┆             ┆       ┆            ┆ have car   ┆            ┆            │
# │          ┆ …           ┆             ┆       ┆            ┆ where…     ┆            ┆            │
# │ 000d118  ┆ Many people ┆ Car-free    ┆ 3     ┆ false      ┆ [MASK]Many ┆ [1, 10, …  ┆ <Claim>    │
# │          ┆ have car    ┆ cities      ┆       ┆            ┆ people     ┆ 596]       ┆            │
# │          ┆ where they  ┆             ┆       ┆            ┆ have car   ┆            ┆            │
# │          ┆ …           ┆             ┆       ┆            ┆ where…     ┆            ┆            │
# │ 000d118  ┆ Many people ┆ Car-free    ┆ 3     ┆ false      ┆ [MASK]Many ┆ [1, 10, …  ┆ <Evidence> │
# │          ┆ have car    ┆ cities      ┆       ┆            ┆ people     ┆ 596]       ┆            │
# │          ┆ where they  ┆             ┆       ┆            ┆ have car   ┆            ┆            │
# │          ┆ …           ┆             ┆       ┆            ┆ where…     ┆            ┆            │
# │ 000d118  ┆ Many people ┆ Car-free    ┆ 3     ┆ false      ┆ [MASK]Many ┆ [1, 10, …  ┆            │
# │          ┆ have car    ┆ cities      ┆       ┆            ┆ people     ┆ 596]       ┆            │
# │          ┆ where they  ┆             ┆       ┆            ┆ have car   ┆            ┆            │
# │          ┆ …           ┆             ┆       ┆            ┆ where…     ┆            ┆            │
# │ …        ┆ …           ┆ …           ┆ …     ┆ …          ┆ …          ┆ …          ┆ …          │
# │ fffed3e  ┆ Venus is    ┆ Exploring   ┆ 2     ┆ true       ┆ [MASK]Venu ┆ [1, 11, …  ┆ <Evidence> │
# │          ┆ worthy      ┆ Venus       ┆       ┆            ┆ s is       ┆ 167]       ┆            │
# │          ┆ place to    ┆             ┆       ┆            ┆ worthy     ┆            ┆            │
# │          ┆ study b…    ┆             ┆       ┆            ┆ place to   ┆            ┆            │
# │          ┆             ┆             ┆       ┆            ┆ s…         ┆            ┆            │
# │ fffed3e  ┆ Venus is    ┆ Exploring   ┆ 2     ┆ true       ┆ [MASK]Venu ┆ [1, 11, …  ┆            │
# │          ┆ worthy      ┆ Venus       ┆       ┆            ┆ s is       ┆ 167]       ┆            │
# │          ┆ place to    ┆             ┆       ┆            ┆ worthy     ┆            ┆            │
# │          ┆ study b…    ┆             ┆       ┆            ┆ place to   ┆            ┆            │
# │          ┆             ┆             ┆       ┆            ┆ s…         ┆            ┆            │
# │ fffed3e  ┆ Venus is    ┆ Exploring   ┆ 2     ┆ true       ┆ [MASK]Venu ┆ [1, 11, …  ┆ <Rebuttal> │
# │          ┆ worthy      ┆ Venus       ┆       ┆            ┆ s is       ┆ 167]       ┆            │
# │          ┆ place to    ┆             ┆       ┆            ┆ worthy     ┆            ┆            │
# │          ┆ study b…    ┆             ┆       ┆            ┆ place to   ┆            ┆            │
# │          ┆             ┆             ┆       ┆            ┆ s…         ┆            ┆            │
# │ fffed3e  ┆ Venus is    ┆ Exploring   ┆ 2     ┆ true       ┆ [MASK]Venu ┆ [1, 11, …  ┆            │
# │          ┆ worthy      ┆ Venus       ┆       ┆            ┆ s is       ┆ 167]       ┆            │
# │          ┆ place to    ┆             ┆       ┆            ┆ worthy     ┆            ┆            │
# │          ┆ study b…    ┆             ┆       ┆            ┆ place to   ┆            ┆            │
# │          ┆             ┆             ┆       ┆            ┆ s…         ┆            ┆            │
# │ fffed3e  ┆ Venus is    ┆ Exploring   ┆ 2     ┆ true       ┆ [MASK]Venu ┆ [1, 11, …  ┆ <Concludin │
# │          ┆ worthy      ┆ Venus       ┆       ┆            ┆ s is       ┆ 167]       ┆ g>         │
# │          ┆ place to    ┆             ┆       ┆            ┆ worthy     ┆            ┆            │
# │          ┆ study b…    ┆             ┆       ┆            ┆ place to   ┆            ┆            │
# │          ┆             ┆             ┆       ┆            ┆ s…         ┆            ┆            │
# └──────────┴─────────────┴─────────────┴───────┴────────────┴────────────┴────────────┴────────────┘

# %%
# tmp = mlm_preds.explode('preds').with_columns(pl.col('preds').replace(mlm_token_map, return_dtype=pl.String))
# tmp

# %%
# new_s_token = []

# for name, data in tmp.group_by(['essay_id', 'full_text'], maintain_order=True):

#     rev_s_token = ','.join(data['preds'].reverse().to_list())
#     t_len = data.group_by("preds").len()
    
#     for k in t_len.to_dicts():
#         if k['preds'] == '<Concluding>':
#             if k['len'] > 1:
#                 conclude_occur = rev_s_token.count('<Concluding>')
#                 rev_s_token = rev_s_token.replace('<Concluding>', '', conclude_occur - 1)

#     new_s_token.extend(reversed(rev_s_token.split(',')))

# %%
# tmp = tmp.with_columns(preds=pl.Series(new_s_token))
# tmp

# %%
masked_list = []
for name, data in tmp.group_by(['essay_id', 'full_text', 'prompt_name', 'score', 'kaggle_only'], maintain_order=True):
    s_token = data['preds'].to_list()
    masked = data['masked'][0]
    
    for token in s_token:
        masked = masked.replace('[MASK]', token, 1)
    
    masked_list.append(masked)

# %%
mlm_preds = mlm_preds.with_columns(tokened_text=pl.Series(masked_list).str.replace_all('\[(MASK)\]', ''))
mlm_preds
# Out:
# shape: (17_305, 9)
# ┌──────────┬────────────┬────────────┬───────┬───┬────────────┬────────────┬───────────┬───────────┐
# │ essay_id ┆ full_text  ┆ prompt_nam ┆ score ┆ … ┆ masked     ┆ deberta_la ┆ preds     ┆ tokened_t │
# │ ---      ┆ ---        ┆ e          ┆ ---   ┆   ┆ ---        ┆ bels_idx   ┆ ---       ┆ ext       │
# │ str      ┆ str        ┆ ---        ┆ i64   ┆   ┆ str        ┆ ---        ┆ list[i64] ┆ ---       │
# │          ┆            ┆ str        ┆       ┆   ┆            ┆ list[i64]  ┆           ┆ str       │
# ╞══════════╪════════════╪════════════╪═══════╪═══╪════════════╪════════════╪═══════════╪═══════════╡
# │ 000d118  ┆ Many       ┆ Car-free   ┆ 3     ┆ … ┆ [MASK]Many ┆ [1, 10, …  ┆ [128003,  ┆ <Lead>Man │
# │          ┆ people     ┆ cities     ┆       ┆   ┆ people     ┆ 596]       ┆ 128006, … ┆ y people  │
# │          ┆ have car   ┆            ┆       ┆   ┆ have car   ┆            ┆ 128004]   ┆ have car  │
# │          ┆ where they ┆            ┆       ┆   ┆ where…     ┆            ┆           ┆ where…    │
# │          ┆ …          ┆            ┆       ┆   ┆            ┆            ┆           ┆           │
# │ 000fe60  ┆ I am a     ┆ The Face   ┆ 3     ┆ … ┆ [MASK]I am ┆ [1, 18, …  ┆ [128003,  ┆ <Lead>I   │
# │          ┆ scientist  ┆ on Mars    ┆       ┆   ┆ a          ┆ 379]       ┆ 128004, … ┆ am a      │
# │          ┆ at NASA    ┆            ┆       ┆   ┆ scientist  ┆            ┆ 128007]   ┆ scientist │
# │          ┆ that is…   ┆            ┆       ┆   ┆ at NASA t… ┆            ┆           ┆ at NASA   │
# │          ┆            ┆            ┆       ┆   ┆            ┆            ┆           ┆ t…        │
# │ 001ab80  ┆ People     ┆ Driverless ┆ 4     ┆ … ┆ [MASK]Peop ┆ [1, 31, …  ┆ [128003,  ┆ <Lead>Peo │
# │          ┆ always     ┆ cars       ┆       ┆   ┆ le always  ┆ 637]       ┆ 128004, … ┆ ple       │
# │          ┆ wish they  ┆            ┆       ┆   ┆ wish they  ┆            ┆ 128007]   ┆ always    │
# │          ┆ had the …  ┆            ┆       ┆   ┆ ha…        ┆            ┆           ┆ wish they │
# │          ┆            ┆            ┆       ┆   ┆            ┆            ┆           ┆ ha…       │
# │ 001bdc0  ┆ We all     ┆ Exploring  ┆ 4     ┆ … ┆ [MASK]We   ┆ [1, 72, …  ┆ [128003,  ┆ <Lead>We  │
# │          ┆ heard      ┆ Venus      ┆       ┆   ┆ all heard  ┆ 537]       ┆ 128005, … ┆ all heard │
# │          ┆ about      ┆            ┆       ┆   ┆ about      ┆            ┆ 128007]   ┆ about     │
# │          ┆ Venus, the ┆            ┆       ┆   ┆ Venus, …   ┆            ┆           ┆ Venus, …  │
# │          ┆ pl…        ┆            ┆       ┆   ┆            ┆            ┆           ┆           │
# │ 002ba53  ┆ Dear,      ┆ Does the   ┆ 3     ┆ … ┆ [MASK]Dear ┆ [1, 20, …  ┆ [128003,  ┆ <Lead>Dea │
# │          ┆ State      ┆ electoral  ┆       ┆   ┆ , State    ┆ 455]       ┆ 128006, … ┆ r, State  │
# │          ┆ Senator    ┆ college    ┆       ┆   ┆ Senator[PA ┆            ┆ 128007]   ┆ Senator[P │
# │          ┆            ┆ work?      ┆       ┆   ┆ RAGR…      ┆            ┆           ┆ ARAGR…    │
# │          ┆ This is a  ┆            ┆       ┆   ┆            ┆            ┆           ┆           │
# │          ┆ l…         ┆            ┆       ┆   ┆            ┆            ┆           ┆           │
# │ …        ┆ …          ┆ …          ┆ …     ┆ … ┆ …          ┆ …          ┆ …         ┆ …         │
# │ ffd378d  ┆ the story  ┆ Exploring  ┆ 2     ┆ … ┆ [MASK]the  ┆ [1, 29, …  ┆ [128003,  ┆ <Lead>the │
# │          ┆ " The      ┆ Venus      ┆       ┆   ┆ story "    ┆ 185]       ┆ 128005, … ┆ story "   │
# │          ┆ Challenge  ┆            ┆       ┆   ┆ The        ┆            ┆ 128007]   ┆ The       │
# │          ┆ of Exp…    ┆            ┆       ┆   ┆ Challenge  ┆            ┆           ┆ Challenge │
# │          ┆            ┆            ┆       ┆   ┆ …          ┆            ┆           ┆ …         │
# │ ffddf1f  ┆ Technology ┆ Facial     ┆ 4     ┆ … ┆ [MASK]Tech ┆ [1, 14, …  ┆ [128003,  ┆ <Lead>Tec │
# │          ┆ has        ┆ action     ┆       ┆   ┆ nology has ┆ 682]       ┆ 128006, … ┆ hnology   │
# │          ┆ changed a  ┆ coding     ┆       ┆   ┆ changed a  ┆            ┆ 128007]   ┆ has       │
# │          ┆ lot of …   ┆ system     ┆       ┆   ┆ l…         ┆            ┆           ┆ changed a │
# │          ┆            ┆            ┆       ┆   ┆            ┆            ┆           ┆ l…        │
# │ fff016d  ┆ If you     ┆ "A Cowboy  ┆ 2     ┆ … ┆ [MASK]If   ┆ [1, 27, …  ┆ [128003,  ┆ <Lead>If  │
# │          ┆ don't like ┆ Who Rode   ┆       ┆   ┆ you don't  ┆ 249]       ┆ 128004, … ┆ you don't │
# │          ┆ sitting    ┆ the Waves" ┆       ┆   ┆ like       ┆            ┆ 128007]   ┆ like      │
# │          ┆ around…    ┆            ┆       ┆   ┆ sitting …  ┆            ┆           ┆ sitting … │
# │ fffb49b  ┆ In "The    ┆ Exploring  ┆ 1     ┆ … ┆ [MASK]In   ┆ [1, 46, …  ┆ [128004,  ┆ <Position │
# │          ┆ Challenge  ┆ Venus      ┆       ┆   ┆ "The       ┆ 267]       ┆ 128006, … ┆ >In "The  │
# │          ┆ of         ┆            ┆       ┆   ┆ Challenge  ┆            ┆ 128007]   ┆ Challenge │
# │          ┆ Exporing   ┆            ┆       ┆   ┆ of Expor…  ┆            ┆           ┆ of E…     │
# │          ┆ Ve…        ┆            ┆       ┆   ┆            ┆            ┆           ┆           │
# │ fffed3e  ┆ Venus is   ┆ Exploring  ┆ 2     ┆ … ┆ [MASK]Venu ┆ [1, 11, …  ┆ [128004,  ┆ <Position │
# │          ┆ worthy     ┆ Venus      ┆       ┆   ┆ s is       ┆ 167]       ┆ 128005, … ┆ >Venus is │
# │          ┆ place to   ┆            ┆       ┆   ┆ worthy     ┆            ┆ 128007]   ┆ worthy    │
# │          ┆ study b…   ┆            ┆       ┆   ┆ place to   ┆            ┆           ┆ place …   │
# │          ┆            ┆            ┆       ┆   ┆ s…         ┆            ┆           ┆           │
# └──────────┴────────────┴────────────┴───────┴───┴────────────┴────────────┴───────────┴───────────┘

# %%
mlm_preds = mlm_preds.select(['essay_id', 'full_text', 'prompt_name', 'score', 'kaggle_only', 'tokened_text'])
mlm_preds
# Out:
# shape: (17_305, 6)
# ┌──────────┬─────────────────────┬─────────────────────┬───────┬─────────────┬─────────────────────┐
# │ essay_id ┆ full_text           ┆ prompt_name         ┆ score ┆ kaggle_only ┆ tokened_text        │
# │ ---      ┆ ---                 ┆ ---                 ┆ ---   ┆ ---         ┆ ---                 │
# │ str      ┆ str                 ┆ str                 ┆ i64   ┆ bool        ┆ str                 │
# ╞══════════╪═════════════════════╪═════════════════════╪═══════╪═════════════╪═════════════════════╡
# │ 000d118  ┆ Many people have    ┆ Car-free cities     ┆ 3     ┆ false       ┆ <Lead>Many people   │
# │          ┆ car where they …    ┆                     ┆       ┆             ┆ have car where…     │
# │ 000fe60  ┆ I am a scientist at ┆ The Face on Mars    ┆ 3     ┆ true        ┆ <Lead>I am a        │
# │          ┆ NASA that is…       ┆                     ┆       ┆             ┆ scientist at NASA   │
# │          ┆                     ┆                     ┆       ┆             ┆ t…                  │
# │ 001ab80  ┆ People always wish  ┆ Driverless cars     ┆ 4     ┆ true        ┆ <Lead>People always │
# │          ┆ they had the …      ┆                     ┆       ┆             ┆ wish they ha…       │
# │ 001bdc0  ┆ We all heard about  ┆ Exploring Venus     ┆ 4     ┆ true        ┆ <Lead>We all heard  │
# │          ┆ Venus, the pl…      ┆                     ┆       ┆             ┆ about Venus, …      │
# │ 002ba53  ┆ Dear, State Senator ┆ Does the electoral  ┆ 3     ┆ false       ┆ <Lead>Dear, State   │
# │          ┆                     ┆ college work?       ┆       ┆             ┆ Senator[PARAGR…     │
# │          ┆ This is a l…        ┆                     ┆       ┆             ┆                     │
# │ …        ┆ …                   ┆ …                   ┆ …     ┆ …           ┆ …                   │
# │ ffd378d  ┆ the story " The     ┆ Exploring Venus     ┆ 2     ┆ true        ┆ <Lead>the story "   │
# │          ┆ Challenge of Exp…   ┆                     ┆       ┆             ┆ The Challenge …     │
# │ ffddf1f  ┆ Technology has      ┆ Facial action       ┆ 4     ┆ false       ┆ <Lead>Technology    │
# │          ┆ changed a lot of …  ┆ coding system       ┆       ┆             ┆ has changed a l…    │
# │ fff016d  ┆ If you don't like   ┆ "A Cowboy Who Rode  ┆ 2     ┆ false       ┆ <Lead>If you don't  │
# │          ┆ sitting around…     ┆ the Waves"          ┆       ┆             ┆ like sitting …      │
# │ fffb49b  ┆ In "The Challenge   ┆ Exploring Venus     ┆ 1     ┆ false       ┆ <Position>In "The   │
# │          ┆ of Exporing Ve…     ┆                     ┆       ┆             ┆ Challenge of E…     │
# │ fffed3e  ┆ Venus is worthy     ┆ Exploring Venus     ┆ 2     ┆ true        ┆ <Position>Venus is  │
# │          ┆ place to study b…   ┆                     ┆       ┆             ┆ worthy place …      │
# └──────────┴─────────────────────┴─────────────────────┴───────┴─────────────┴─────────────────────┘

# %%
mlm_combined_token = mlm_preds.with_columns(pl.col('tokened_text').str.replace_all(pat_1, pat_2))
mlm_combined_token
# Out:
# shape: (17_305, 6)
# ┌──────────┬─────────────────────┬─────────────────────┬───────┬─────────────┬─────────────────────┐
# │ essay_id ┆ full_text           ┆ prompt_name         ┆ score ┆ kaggle_only ┆ tokened_text        │
# │ ---      ┆ ---                 ┆ ---                 ┆ ---   ┆ ---         ┆ ---                 │
# │ str      ┆ str                 ┆ str                 ┆ i64   ┆ bool        ┆ str                 │
# ╞══════════╪═════════════════════╪═════════════════════╪═══════╪═════════════╪═════════════════════╡
# │ 000d118  ┆ Many people have    ┆ Car-free cities     ┆ 3     ┆ false       ┆ <Lead>Many people   │
# │          ┆ car where they …    ┆                     ┆       ┆             ┆ have car where…     │
# │ 000fe60  ┆ I am a scientist at ┆ The Face on Mars    ┆ 3     ┆ true        ┆ <Lead>I am a        │
# │          ┆ NASA that is…       ┆                     ┆       ┆             ┆ scientist at NASA   │
# │          ┆                     ┆                     ┆       ┆             ┆ t…                  │
# │ 001ab80  ┆ People always wish  ┆ Driverless cars     ┆ 4     ┆ true        ┆ <Lead>People always │
# │          ┆ they had the …      ┆                     ┆       ┆             ┆ wish they ha…       │
# │ 001bdc0  ┆ We all heard about  ┆ Exploring Venus     ┆ 4     ┆ true        ┆ <Lead>We all heard  │
# │          ┆ Venus, the pl…      ┆                     ┆       ┆             ┆ about Venus, …      │
# │ 002ba53  ┆ Dear, State Senator ┆ Does the electoral  ┆ 3     ┆ false       ┆ <Lead>Dear, State   │
# │          ┆                     ┆ college work?       ┆       ┆             ┆ Senator[PARAGR…     │
# │          ┆ This is a l…        ┆                     ┆       ┆             ┆                     │
# │ …        ┆ …                   ┆ …                   ┆ …     ┆ …           ┆ …                   │
# │ ffd378d  ┆ the story " The     ┆ Exploring Venus     ┆ 2     ┆ true        ┆ <Lead>the story "   │
# │          ┆ Challenge of Exp…   ┆                     ┆       ┆             ┆ The Challenge …     │
# │ ffddf1f  ┆ Technology has      ┆ Facial action       ┆ 4     ┆ false       ┆ <Lead>Technology    │
# │          ┆ changed a lot of …  ┆ coding system       ┆       ┆             ┆ has changed a l…    │
# │ fff016d  ┆ If you don't like   ┆ "A Cowboy Who Rode  ┆ 2     ┆ false       ┆ <Lead>If you don't  │
# │          ┆ sitting around…     ┆ the Waves"          ┆       ┆             ┆ like sitting …      │
# │ fffb49b  ┆ In "The Challenge   ┆ Exploring Venus     ┆ 1     ┆ false       ┆ <Position>In "The   │
# │          ┆ of Exporing Ve…     ┆                     ┆       ┆             ┆ Challenge of E…     │
# │ fffed3e  ┆ Venus is worthy     ┆ Exploring Venus     ┆ 2     ┆ true        ┆ <Position>Venus is  │
# │          ┆ place to study b…   ┆                     ┆       ┆             ┆ worthy place …      │
# └──────────┴─────────────────────┴─────────────────────┴───────┴─────────────┴─────────────────────┘

# %%
mlm_combined_token.write_csv('train_mlm_combined_tokened_M007.csv')

# %%
tt = mlm_combined_token.with_columns([pl.col('tokened_text').str.count_matches(count_dt[i]).alias(f'{rev_dt_map[i]}' +'_count') for i in range(7)]).group_by(['score']).mean().sort('score')
tt.drop(['full_text', 'prompt_name', 'masked', 'deberta_labels_idx', 'preds', 'tokened_text']).to_pandas().style.background_gradient()
# Out:
# <style type="text/css">
# #T_84b9e_row0_col0, #T_84b9e_row0_col4, #T_84b9e_row0_col5, #T_84b9e_row0_col6, #T_84b9e_row0_col7, #T_84b9e_row0_col8, #T_84b9e_row0_col9, #T_84b9e_row1_col3, #T_84b9e_row1_col5, #T_84b9e_row1_col9, #T_84b9e_row5_col2 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_84b9e_row0_col2 {
#   background-color: #328dbf;
#   color: #f1f1f1;
# }
# #T_84b9e_row0_col3 {
#   background-color: #dddbec;
#   color: #000000;
# }
# #T_84b9e_row1_col0 {
#   background-color: #dbdaeb;
#   color: #000000;
# }
# #T_84b9e_row1_col2 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_84b9e_row1_col4 {
#   background-color: #75a9cf;
#   color: #f1f1f1;
# }
# #T_84b9e_row1_col6 {
#   background-color: #f5eef6;
#   color: #000000;
# }
# #T_84b9e_row1_col7 {
#   background-color: #91b5d6;
#   color: #000000;
# }
# #T_84b9e_row1_col8 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_84b9e_row2_col0 {
#   background-color: #9cb9d9;
#   color: #000000;
# }
# #T_84b9e_row2_col2 {
#   background-color: #0f76b3;
#   color: #f1f1f1;
# }
# #T_84b9e_row2_col3 {
#   background-color: #bdc8e1;
#   color: #000000;
# }
# #T_84b9e_row2_col4 {
#   background-color: #0872b1;
#   color: #f1f1f1;
# }
# #T_84b9e_row2_col5 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_84b9e_row2_col6 {
#   background-color: #c0c9e2;
#   color: #000000;
# }
# #T_84b9e_row2_col7 {
#   background-color: #0c74b2;
#   color: #f1f1f1;
# }
# #T_84b9e_row2_col8 {
#   background-color: #e2dfee;
#   color: #000000;
# }
# #T_84b9e_row2_col9 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_84b9e_row3_col0 {
#   background-color: #4295c3;
#   color: #f1f1f1;
# }
# #T_84b9e_row3_col2, #T_84b9e_row5_col0, #T_84b9e_row5_col3, #T_84b9e_row5_col4, #T_84b9e_row5_col5, #T_84b9e_row5_col6, #T_84b9e_row5_col7, #T_84b9e_row5_col8, #T_84b9e_row5_col9 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_84b9e_row3_col3 {
#   background-color: #1b7eb7;
#   color: #f1f1f1;
# }
# #T_84b9e_row3_col4 {
#   background-color: #046299;
#   color: #f1f1f1;
# }
# #T_84b9e_row3_col5 {
#   background-color: #67a4cc;
#   color: #f1f1f1;
# }
# #T_84b9e_row3_col6 {
#   background-color: #589ec8;
#   color: #f1f1f1;
# }
# #T_84b9e_row3_col7 {
#   background-color: #034973;
#   color: #f1f1f1;
# }
# #T_84b9e_row3_col8 {
#   background-color: #b3c3de;
#   color: #000000;
# }
# #T_84b9e_row3_col9 {
#   background-color: #c1cae2;
#   color: #000000;
# }
# #T_84b9e_row4_col0 {
#   background-color: #0567a2;
#   color: #f1f1f1;
# }
# #T_84b9e_row4_col2 {
#   background-color: #e3e0ee;
#   color: #000000;
# }
# #T_84b9e_row4_col3 {
#   background-color: #023e62;
#   color: #f1f1f1;
# }
# #T_84b9e_row4_col4 {
#   background-color: #8cb3d5;
#   color: #000000;
# }
# #T_84b9e_row4_col5 {
#   background-color: #046097;
#   color: #f1f1f1;
# }
# #T_84b9e_row4_col6 {
#   background-color: #045a8d;
#   color: #f1f1f1;
# }
# #T_84b9e_row4_col7 {
#   background-color: #023c5f;
#   color: #f1f1f1;
# }
# #T_84b9e_row4_col8 {
#   background-color: #4897c4;
#   color: #f1f1f1;
# }
# #T_84b9e_row4_col9 {
#   background-color: #4e9ac6;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_84b9e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_84b9e_level0_col0" class="col_heading level0 col0" >score</th>
#       <th id="T_84b9e_level0_col1" class="col_heading level0 col1" >essay_id</th>
#       <th id="T_84b9e_level0_col2" class="col_heading level0 col2" >kaggle_only</th>
#       <th id="T_84b9e_level0_col3" class="col_heading level0 col3" >Lead_count</th>
#       <th id="T_84b9e_level0_col4" class="col_heading level0 col4" >Position_count</th>
#       <th id="T_84b9e_level0_col5" class="col_heading level0 col5" >Claim_count</th>
#       <th id="T_84b9e_level0_col6" class="col_heading level0 col6" >Evidence_count</th>
#       <th id="T_84b9e_level0_col7" class="col_heading level0 col7" >Concluding Statement_count</th>
#       <th id="T_84b9e_level0_col8" class="col_heading level0 col8" >Counterclaim_count</th>
#       <th id="T_84b9e_level0_col9" class="col_heading level0 col9" >Rebuttal_count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_84b9e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_84b9e_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_84b9e_row0_col1" class="data row0 col1" >None</td>
#       <td id="T_84b9e_row0_col2" class="data row0 col2" >0.245208</td>
#       <td id="T_84b9e_row0_col3" class="data row0 col3" >0.486422</td>
#       <td id="T_84b9e_row0_col4" class="data row0 col4" >0.890575</td>
#       <td id="T_84b9e_row0_col5" class="data row0 col5" >2.545527</td>
#       <td id="T_84b9e_row0_col6" class="data row0 col6" >2.369010</td>
#       <td id="T_84b9e_row0_col7" class="data row0 col7" >0.579872</td>
#       <td id="T_84b9e_row0_col8" class="data row0 col8" >0.255591</td>
#       <td id="T_84b9e_row0_col9" class="data row0 col9" >0.232428</td>
#     </tr>
#     <tr>
#       <th id="T_84b9e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_84b9e_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_84b9e_row1_col1" class="data row1 col1" >None</td>
#       <td id="T_84b9e_row1_col2" class="data row1 col2" >0.214059</td>
#       <td id="T_84b9e_row1_col3" class="data row1 col3" >0.424518</td>
#       <td id="T_84b9e_row1_col4" class="data row1 col4" >0.938598</td>
#       <td id="T_84b9e_row1_col5" class="data row1 col5" >2.536312</td>
#       <td id="T_84b9e_row1_col6" class="data row1 col6" >2.536947</td>
#       <td id="T_84b9e_row1_col7" class="data row1 col7" >0.862587</td>
#       <td id="T_84b9e_row1_col8" class="data row1 col8" >0.348931</td>
#       <td id="T_84b9e_row1_col9" class="data row1 col9" >0.228880</td>
#     </tr>
#     <tr>
#       <th id="T_84b9e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_84b9e_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_84b9e_row2_col1" class="data row2 col1" >None</td>
#       <td id="T_84b9e_row2_col2" class="data row2 col2" >0.266168</td>
#       <td id="T_84b9e_row2_col3" class="data row2 col3" >0.522300</td>
#       <td id="T_84b9e_row2_col4" class="data row2 col4" >0.962249</td>
#       <td id="T_84b9e_row2_col5" class="data row2 col5" >3.344059</td>
#       <td id="T_84b9e_row2_col6" class="data row2 col6" >3.116279</td>
#       <td id="T_84b9e_row2_col7" class="data row2 col7" >1.066263</td>
#       <td id="T_84b9e_row2_col8" class="data row2 col8" >0.560688</td>
#       <td id="T_84b9e_row2_col9" class="data row2 col9" >0.402517</td>
#     </tr>
#     <tr>
#       <th id="T_84b9e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_84b9e_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_84b9e_row3_col1" class="data row3 col1" >None</td>
#       <td id="T_84b9e_row3_col2" class="data row3 col2" >0.330871</td>
#       <td id="T_84b9e_row3_col3" class="data row3 col3" >0.645186</td>
#       <td id="T_84b9e_row3_col4" class="data row3 col4" >0.970708</td>
#       <td id="T_84b9e_row3_col5" class="data row3 col5" >4.214213</td>
#       <td id="T_84b9e_row3_col6" class="data row3 col6" >3.763627</td>
#       <td id="T_84b9e_row3_col7" class="data row3 col7" >1.200204</td>
#       <td id="T_84b9e_row3_col8" class="data row3 col8" >0.856342</td>
#       <td id="T_84b9e_row3_col9" class="data row3 col9" >0.658686</td>
#     </tr>
#     <tr>
#       <th id="T_84b9e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_84b9e_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_84b9e_row4_col1" class="data row4 col1" >None</td>
#       <td id="T_84b9e_row4_col2" class="data row4 col2" >0.135052</td>
#       <td id="T_84b9e_row4_col3" class="data row4 col3" >0.736082</td>
#       <td id="T_84b9e_row4_col4" class="data row4 col4" >0.932990</td>
#       <td id="T_84b9e_row4_col5" class="data row4 col5" >5.209278</td>
#       <td id="T_84b9e_row4_col6" class="data row4 col6" >4.555670</td>
#       <td id="T_84b9e_row4_col7" class="data row4 col7" >1.231959</td>
#       <td id="T_84b9e_row4_col8" class="data row4 col8" >1.300000</td>
#       <td id="T_84b9e_row4_col9" class="data row4 col9" >1.062887</td>
#     </tr>
#     <tr>
#       <th id="T_84b9e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_84b9e_row5_col0" class="data row5 co

# %%
# 3d13ded
